# %%
import requests

youbike_url = 'https://data.ntpc.gov.tw/api/datasets/010e5b15-3823-4b20-b401-b1cf000550c5/json?size=2000'
try:
    response = requests.get(youbike_url)
except Exception as e:
    print(e)
else:
    print(response.text)
# Out:
# [{"sno":"500201001","sna":"YouBike2.0_下庄市場","tot":"20","sbi":"3","sarea":"八里區","mday":"20240622142120","lat":"25.14678","lng":"121.3999","ar":"舊城路21號(前)","sareaen":"Bali Dist","snaen":"YouBike2.0_Shia Juang Market","aren":"No.21, Jiucheng Rd., Bali Dist","bemp":"17","act":"1"},{"sno":"500201002","sna":"YouBike2.0_八里行政中心","tot":"20","sbi":"2","sarea":"八里區","mday":"20240622144220","lat":"25.15397","lng":"121.40721","ar":"十三行路(靠中山路二段路口西南側人行道)","sareaen":"Bali Dist","snaen":"YouBike2.0_Bali District Center","aren":"Shisanhang Rd. & Zhongshan Rd. Intersection (Southwest)","bemp":"18","act":"1"},{"sno":"500201003","sna":"YouBike2.0_八里中庄市場綜合大樓","tot":"28","sbi":"1","sarea":"八里區","mday":"20240622134120","lat":"25.15993","lng":"121.41407","ar":"中山路一段268巷2號(對面汽車停車場)","sareaen":"Bali Dist","snaen":"YouBike2.0_Bali Chung Chuang Market Multi-Purpose Building","aren":"No. 2, Ln. 268, Sec. 1, Zhongshan Rd., Bali Dist.","bemp":"27","act":"1"},{"sno":"500201004","sna":"YouBike2.0_大崁國小","tot":"20","sbi":"7","sarea":"八里區","mday":"20240622142720","lat":"25.16064","lng":"121.41938","ar":"忠八街2號(前)","sareaen":"Bali Dist","snaen":"YouBike2.0_DaKan Elementary School","aren":"No. 2, Zhong 8th St., Bali Dist.","bemp":"13","act":"1"},{"sno":"500201005","sna":"YouBike2.0_龍米停車場","tot":"32","sbi":"12","sarea":"八里區","mday":"20240622144923","lat":"25.15678","lng":"121.43604","ar":"龍米路二段150號(旁)","sareaen":"Bali Dist","snaen":"YouBike2.0_Longmi Parking Lot","aren":"No. 150, Sec. 2, Longmi Rd.","bemp":"20","act":"1"},{"sno":"500201006","sna":"YouBike2.0_龍形停車場","tot":"40","sbi":"5","sarea":"八里區","mday":"20240622144120","lat":"25.13041","lng":"121.4513","ar":"龍米路一段318號(對面停車場)","sareaen":"Bali Dist","snaen":"YouBike2.0_Long Xing Parking Tower","aren":"No. 318, Sec 1, Longmi Rd.(Opposite)","bemp":"35","act":"1"},{"sno":"500201007","sna":"YouBike2.0_十三行博物館","tot":"46","sbi":"18","sarea":"八里區","mday":"20240622145420","lat":"25.157","lng":"121.406","ar":"博物館路183號(對面)","sareaen":"Bali Dist","snaen":"YouBike2.0_Shihsanhang Museum of Archaeology","aren":"No. 183, Museum Rd., Bali Dist.(opposite)","bemp":"28","act":"1"},{"sno":"500201008","sna":"YouBike2.0_八里區民活動中心","tot":"14","sbi":"8","sarea":"八里區","mday":"20240622144220","lat":"25.14933","lng":"121.40126","ar":"中山路二段356巷12號(旁)","sareaen":"Bali Dist","snaen":"YouBike2.0_Bali Activity Center","aren":"No. 12, Ln. 356, Sec. 2, Zhongshan Rd.","bemp":"6","act":"1"},{"sno":"500201009","sna":"YouBike2.0_挖仔尾自然生態保留區","tot":"15","sbi":"6","sarea":"八里區","mday":"20240622141106","lat":"25.16419","lng":"121.41586","ar":"博物館路/挖仔尾街口(西側)","sareaen":"Bali Dist","snaen":"YouBike2.0_Waziwei Ecological Reserves","aren":"Museum Rd. & Waziwei St. Intersection(West)","bemp":"9","act":"1"},{"sno":"500201010","sna":"YouBike2.0_文昌公園","tot":"15","sbi":"8","sarea":"八里區","mday":"20240622143522","lat":"25.15709","lng":"121.41033","ar":"中山路二段/文昌路(東側)","sareaen":"Bali Dist","snaen":"YouBike2.0_Wenchang Park","aren":"Sec. 2, Zhongshan Rd. & Wenchang Rd.(East)","bemp":"7","act":"1"},{"sno":"500201011","sna":"YouBike2.0_八里國小","tot":"15","sbi":"2","sarea":"八里區","mday":"20240622142220","lat":"25.14896","lng":"121.4026","ar":"中山路二段251號(對面)","sareaen":"Bali Dist","snaen":"YouBike2.0_Bali Elementary School","aren":"No. 251, Sec. 2, Zhongshan Rd.(Opposite)","bemp":"13","act":"1"},{"sno":"500201012","sna":"YouBike2.0_八里文化公園(棒球場)","tot":"30","sbi":"6","sarea":"八里區","mday":"20240622133819","lat":"25.16359","lng":"121.41251","ar":"忠孝路與挖仔街口(棒球場公園入口)","sareaen":"Bali Dist","snaen":"YouBike2.0_Bali Wenhua Park","aren":"Zhongxiao & Waziwei street entrance (baseball park)","bemp":"24","act":"1"},{"sno":"500201013","sna":"YouBike2.0_水興公","tot":"15","sbi":"3","sarea":"八里區","mday":"20240622133120","lat":"25.16208","lng":"121.42509","ar":"觀海大道/忠四街(北側)","sareaen":"Bali Dist","snaen":"YouBike2.0_Shuixinggong","aren":"Guanhai Blvd. & Zhong 4th St. (North west)","bemp":"12","act":"1"},{"sno":"500201014","sna":"YouBike2.0_片仔溝公園","tot":"20","sbi":"7","sarea":"八里區","mday":"20240622 ...

# %%
from pydantic import BaseModel,Field,RootModel,field_validator,field_serializer
from pprint import pprint

class Site(BaseModel):
    站點名稱:str = Field(alias="sna")
    行政區:str = Field(alias="sarea")
    日期時間:str = Field(alias='mday')
    地址:str = Field(alias='ar')
    總數:int = Field(alias='tot')
    可借:int = Field(alias='sbi')
    可還:int = Field(alias='bemp')
    狀態:bool = Field(alias='act')
    緯度:float = Field(alias='lat')
    經度:float = Field(alias='lng')

    @field_validator('站點名稱',mode='before')
    @classmethod
    def abc(cls,value):
        return value.split('_')[-1]
    
    @field_validator('日期時間',mode='before')
    @classmethod
    def abcd(cls,value):
        return f'{value[:4]}-{value[4:6]}-{value[6:8]} {value[8:10]}:{value[10:12]}:{value[12:]}'
    
    @field_serializer('狀態')
    def abce(self,value):
        if value:
            return "營業中"
        else:
            return "維護中"


class Root(RootModel):
    root:list[Site]


root = Root.model_validate_json(response.text)
data = root.model_dump()
pprint(data)
# Out:
# [{'可借': 3,
#   '可還': 17,
#   '地址': '舊城路21號(前)',
#   '日期時間': '2024-06-22 14:21:20',
#   '狀態': '營業中',
#   '站點名稱': '下庄市場',
#   '經度': 121.3999,
#   '緯度': 25.14678,
#   '總數': 20,
#   '行政區': '八里區'},
#  {'可借': 2,
#   '可還': 18,
#   '地址': '十三行路(靠中山路二段路口西南側人行道)',
#   '日期時間': '2024-06-22 14:42:20',
#   '狀態': '營業中',
#   '站點名稱': '八里行政中心',
#   '經度': 121.40721,
#   '緯度': 25.15397,
#   '總數': 20,
#   '行政區': '八里區'},
#  {'可借': 1,
#   '可還': 27,
#   '地址': '中山路一段268巷2號(對面汽車停車場)',
#   '日期時間': '2024-06-22 13:41:20',
#   '狀態': '營業中',
#   '站點名稱': '八里中庄市場綜合大樓',
#   '經度': 121.41407,
#   '緯度': 25.15993,
#   '總數': 28,
#   '行政區': '八里區'},
#  {'可借': 7,
#   '可還': 13,
#   '地址': '忠八街2號(前)',
#   '日期時間': '2024-06-22 14:27:20',
#   '狀態': '營業中',
#   '站點名稱': '大崁國小',
#   '經度': 121.41938,
#   '緯度': 25.16064,
#   '總數': 20,
#   '行政區': '八里區'},
#  {'可借': 12,
#   '可還': 20,
#   '地址': '龍米路二段150號(旁)',
#   '日期時間': '2024-06-22 14:49:23',
#   '狀態': '營業中',
#   '站點名稱': '龍米停車場',
#   '經度': 121.43604,
#   '緯度': 25.15678,
#   '總數': 32,
#   '行政區': '八里區'},
#  {'可借': 5,
#   '可還': 35,
#   '地址': '龍米路一段318號(對面停車場)',
#   '日期時間': '2024-06-22 14:41:20',
#   '狀態': '營業中',
#   '站點名稱': '龍形停車場',
#   '經度': 121.4513,
#   '緯度': 25.13041,
#   '總數': 40,
#   '行政區': '八里區'},
#  {'可借': 18,
#   '可還': 28,
#   '地址': '博物館路183號(對面)',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '十三行博物館',
#   '經度': 121.406,
#   '緯度': 25.157,
#   '總數': 46,
#   '行政區': '八里區'},
#  {'可借': 8,
#   '可還': 6,
#   '地址': '中山路二段356巷12號(旁)',
#   '日期時間': '2024-06-22 14:42:20',
#   '狀態': '營業中',
#   '站點名稱': '八里區民活動中心',
#   '經度': 121.40126,
#   '緯度': 25.14933,
#   '總數': 14,
#   '行政區': '八里區'},
#  {'可借': 6,
#   '可還': 9,
#   '地址': '博物館路/挖仔尾街口(西側)',
#   '日期時間': '2024-06-22 14:11:06',
#   '狀態': '營業中',
#   '站點名稱': '挖仔尾自然生態保留區',
#   '經度': 121.41586,
#   '緯度': 25.16419,
#   '總數': 15,
#   '行政區': '八里區'},
#  {'可借': 8,
#   '可還': 7,
#   '地址': '中山路二段/文昌路(東側)',
#   '日期時間': '2024-06-22 14:35:22',
#   '狀態': '營業中',
#   '站點名稱': '文昌公園',
#   '經度': 121.41033,
#   '緯度': 25.15709,
#   '總數': 15,
#   '行政區': '八里區'},
#  {'可借': 2,
#   '可還': 13,
#   '地址': '中山路二段251號(對面)',
#   '日期時間': '2024-06-22 14:22:20',
#   '狀態': '營業中',
#   '站點名稱': '八里國小',
#   '經度': 121.4026,
#   '緯度': 25.14896,
#   '總數': 15,
#   '行政區': '八里區'},
#  {'可借': 6,
#   '可還': 24,
#   '地址': '忠孝路與挖仔街口(棒球場公園入口)',
#   '日期時間': '2024-06-22 13:38:19',
#   '狀態': '營業中',
#   '站點名稱': '八里文化公園(棒球場)',
#   '經度': 121.41251,
#   '緯度': 25.16359,
#   '總數': 30,
#   '行政區': '八里區'},
#  {'可借': 3,
#   '可還': 12,
#   '地址': '觀海大道/忠四街(北側)',
#   '日期時間': '2024-06-22 13:31:20',
#   '狀態': '營業中',
#   '站點名稱': '水興公',
#   '經度': 121.42509,
#   '緯度': 25.16208,
#   '總數': 15,
#   '行政區': '八里區'},
#  {'可借': 7,
#   '可還': 13,
#   '地址': '中華路二段210號旁',
#   '日期時間': '2024-06-22 14:13:18',
#   '狀態': '營業中',
#   '站點名稱': '片仔溝公園',
#   '經度': 121.40581,
#   '緯度': 25.1502,
#   '總數': 20,
#   '行政區': '八里區'},
#  {'可借': 11,
#   '可還': 7,
#   '地址': '觀海大道8號',
#   '日期時間': '2024-06-22 14:35:23',
#   '狀態': '營業中',
#   '站點名稱': '八里福朋喜來登酒店',
#   '經度': 121.42945,
#   '緯度': 25.15922,
#   '總數': 18,
#   '行政區': '八里區'},
#  {'可借': 1,
#   '可還': 12,
#   '地址': '商港路/中山路二段口(東北側)',
#   '日期時間': '2024-06-22 14:22:56',
#   '狀態': '營業中',
#   '站點名稱': '訊塘社區公園',
#   '經度': 121.39609,
#   '緯度': 25.1455,
#   '總數': 13,
#   '行政區': '八里區'},
#  {'可借': 12,
#   '可還': 3,
#   '地址': '商港八路/商港一路口',
#   '日期時間': '2024-06-22 00:56:19',
#   '狀態': '營業中',
#   '站點名稱': '商港公園(商港八商港一路口)',
#   '經度': 121.40026,
#   '緯度': 25.15039,
#   '總數': 15,
#   '行政區': '八里區'},
#  {'可借': 3,
#   '可還': 12,
#   '地址': '商港七路/商港一路口',
#   '日期時間': '2024-06-22 14:39:21',
#   '狀態': '營業中',
#   '站點名稱': '商港公園(商港七商港一路口)',
#   '經度': 121.39841,
#   '緯度': 25.14916,
#   '總數': 15,
#   '行政區': '八里區'},
#  {'可借': 14,
#   '可還': 19,
#   '地址': '渡船頭路/龍米路二段口(西北側)',
#   '日期時間': '2024-06-22 10:43:19',
#   '狀態': '營業中',
#   '站點名稱': '渡船頭平面停車場',
#   '經度': 121.43527,
#   '緯度': 25.15687,
#   '總數': 33,
#   '行政區': '八里區'},
#  {'可借': 14,
#   '可還': 34,
#   '地址': '北勢子42-11號西側',
#   '日期時間': '2024-06-22 13:49:21',
#   '狀態': '營業中',
#   '站點名稱': '淺水灣',
#   '經度': 121.47131,
#   '緯度': 25.25232,
#   '總數': 48,
#   '行政區': '三芝區'},
#  {'可借': 0,
#   '可還': 13,
#   '地址': '淡金路一段38號',
#   '日期時間': '2024-06-22 14:54:14',
#   '狀態': '營業中',
#   '站點名稱': '三芝國中',
#   '經度': 121.50182,
#   '緯度': 25.25898,
#   '總數': 14,
#   '行政區': '三芝區'},
#  {'可借': 2,
#   '可還': 13,
#   '地址': '埔頭里埔頭11-5號南側',
#   '日期時間': '2024-06-22 09:50:32',
#   '狀態': '營業中',
#   '站點名稱': '櫻花水車公園',
#   '經度': 121.50125,
#   '緯度': 25.25119,
#   '總數': 15,
#   '行政區': '三芝區'},
#  {'可借': 0,
#   '可還': 15,
#   '地址': '長安街79號西側',
#   '日期時間': '2024-06-22 14:53:20',
#   '狀態': '營業中',
#   '站點名稱': '三芝兒一公園',
#   '經度': 121.4994,
#   '緯度': 25.25719,
#   '總數': 15,
#   '行政區': '三芝區'},
#  {'可借': 1,
#   '可還': 14,
#   '地址': '中山路一段32號',
#   '日期時間': '2024-06-22 12:47:16',
#   '狀態': '營業中',
#   '站點名稱': '三芝區公所',
#   '經度': 121.50082,
#   '緯度': 25.25788,
#   '總數': 15,
#   '行政區': '三芝區'},
#  {'可借': 11,
#   '可還': 12,
#   '地址': '重安街1號(旁)',
#   '日期時間': '2024-06-22 14:52:20',
#   '狀態': '營業中',
#   '站點名稱': '重新重安街口',
#   '經度': 121.48975,
#   '緯度': 25.05844,
#   '總數': 23,
#   '行政區': '三重區'},
#  {'可借': 5,
#   '可還': 31,
#   '地址': '集美街225號(對面)',
#   '日期時間': '2024-06-22 14:31:20',
#   '狀態': '營業中',
#   '站點名稱': '三重高中',
#   '經度': 121.49171,
#   '緯度': 25.05478,
#   '總數': 36,
#   '行政區': '三重區'},
#  {'可借': 10,
#   '可還': 14,
#   '地址': '集美街55號(對面)',
#   '日期時間': '2024-06-22 14:53:20',
#   '狀態': '營業中',
#   '站點名稱': '三重國民運動中心',
#   '經度': 121.48849,
#   '緯度': 25.05439,
#   '總數': 24,
#   '行政區': '三重區'},
#  {'可借': 30,
#   '可還': 19,
#   '地址': '捷運路36號(旁)',
#   '日期時間': '2024-06-22 14:50:35',
#   '狀態': '營業中',
#   '站點名稱': '捷運三重站(1號出口)',
#   '經度': 121.48322,
#   '緯度': 25.05464,
#   '總數': 52,
#   '行政區': '三重區'},
#  {'可借': 4,
#   '可還': 17,
#   '地址': '環河南路253號(對面)',
#   '日期時間': '2024-06-22 14:26:19',
#   '狀態': '營業中',
#   '站點名稱': '中興橋(環河南路254巷口)',
#   '經度': 121.49138,
#   '緯度': 25.05052,
#   '總數': 21,
#   '行政區': '三重區'},
#  {'可借': 6,
#   '可還': 19,
#   '地址': '疏洪東路一段38號(前)',
#   '日期時間': '2024-06-22 14:52:19',
#   '狀態': '營業中',
#   '站點名稱': '疏洪東竹圍仔街口',
#   '經度': 121.4864,
#   '緯度': 25.04861,
#   '總數': 25,
#   '行政區': '三重區'},
#  {'可借': 7,
#   '可還': 16,
#   '地址': '福德南路71號(對面)',
#   '日期時間': '2024-06-22 13:44:20',
#   '狀態': '營業中',
#   '站點名稱': '環河福德南路口',
#   '經度': 121.50217,
#   '緯度': 25.06029,
#   '總數': 23,
#   '行政區': '三重區'},
#  {'可借': 4,
#   '可還': 20,
#   '地址': '光興街23號(對面)',
#   '日期時間': '2024-06-22 14:50:35',
#   '狀態': '營業中',
#   '站點名稱': '光興國小',
#   '經度': 121.49978,
#   '緯度': 25.06027,
#   '總數': 24,
#   '行政區': '三重區'},
#  {'可借': 10,
#   '可還': 22,
#   '地址': '大同南路157號(前)',
#   '日期時間': '2024-06-22 14:45:23',
#   '狀態': '營業中',
#   '站點名稱': '三光國小(金滿意)',
#   '經度': 121.49687,
#   '緯度': 25.05596,
#   '總數': 32,
#   '行政區': '三重區'},
#  {'可借': 32,
#   '可還': 17,
#   '地址': '三民路/中華路口(東南側)',
#   '日期時間': '2024-06-22 14:28:20',
#   '狀態': '營業中',
#   '站點名稱': '聯邦公園',
#   '經度': 121.48371,
#   '緯度': 25.06445,
#   '總數': 49,
#   '行政區': '三重區'},
#  {'可借': 5,
#   '可還': 16,
#   '地址': '中華路5號(前)',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '興華公園',
#   '經度': 121.4831,
#   '緯度': 25.06013,
#   '總數': 21,
#   '行政區': '三重區'},
#  {'可借': 14,
#   '可還': 25,
#   '地址': '名源街54號(對面)',
#   '日期時間': '2024-06-22 14:53:20',
#   '狀態': '營業中',
#   '站點名稱': '文中小停車場',
#   '經度': 121.48255,
#   '緯度': 25.05899,
#   '總數': 39,
#   '行政區': '三重區'},
#  {'可借': 27,
#   '可還': 11,
#   '地址': '新北大道一段5巷2弄/過圳街31巷(西南側)',
#   '日期時間': '2024-06-22 14:50:35',
#   '狀態': '營業中',
#   '站點名稱': '三重行政中心',
#   '經度': 121.48823,
#   '緯度': 25.06057,
#   '總數': 38,
#   '行政區': '三重區'},
#  {'可借': 31,
#   '可還': 7,
#   '地址': '重新路三段67號(旁)',
#   '日期時間': '2024-06-22 14:53:19',
#   '狀態': '營業中',
#   '站點名稱': '捷運菜寮站(3號出口)',
#   '經度': 121.4922,
#   '緯度': 25.06047,
#   '總數': 45,
#   '行政區': '三重區'},
#  {'可借': 37,
#   '可還': 9,
#   '地址': '中正北路/中正北路25巷(南側)',
#   '日期時間': '2024-06-22 14:34:18',
#   '狀態': '營業中',
#   '站點名稱': '三重綜合體育館',
#   '經度': 121.49193,
#   '緯度': 25.06145,
#   '總數': 47,
#   '行政區': '三重區'},
#  {'可借': 9,
#   '可還': 11,
#   '地址': '中正北路165巷53號(後竹圍街路側停車格)',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '三重商工(後竹圍街)',
#   '經度': 121.47976,
#   '緯度': 25.07031,
#   '總數': 20,
#   '行政區': '三重區'},
#  {'可借': 13,
#   '可還': 15,
#   '地址': '力行路一段188巷/國道路一段70巷(東南側)',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '力行大勇街口',
#   '經度': 121.48151,
#   '緯度': 25.07193,
#   '總數': 28,
#   '行政區': '三重區'},
#  {'可借': 0,
#   '可還': 34,
#   '地址': '後竹圍街175巷22號(對面)',
#   '日期時間': '2024-06-22 14:47:15',
#   '狀態': '營業中',
#   '站點名稱': '後竹圍市民活動中心',
#   '經度': 121.48576,
#   '緯度': 25.07246,
#   '總數': 34,
#   '行政區': '三重區'},
#  {'可借': 0,
#   '可還': 12,
#   '地址': '忠孝路二段2-1號(旁)',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '和平公園',
#   '經度': 121.48571,
#   '緯度': 25.07088,
#   '總數': 12,
#   '行政區': '三重區'},
#  {'可借': 0,
#   '可還': 40,
#   '地址': '自強路二段74巷91號(對面)',
#   '日期時間': '2024-06-16 09:44:15',
#   '狀態': '維護中',
#   '站點名稱': '六合公園',
#   '經度': 121.48759,
#   '緯度': 25.0695,
#   '總數': 40,
#   '行政區': '三重區'},
#  {'可借': 16,
#   '可還': 22,
#   '地址': '自強路二段47巷57號(對面)',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '三張公園',
#   '經度': 121.49094,
#   '緯度': 25.07051,
#   '總數': 38,
#   '行政區': '三重區'},
#  {'可借': 13,
#   '可還': 22,
#   '地址': '忠孝路一段37號(前)',
#   '日期時間': '2024-06-22 14:17:35',
#   '狀態': '營業中',
#   '站點名稱': '厚德公園',
#   '經度': 121.4912,
#   '緯度': 25.07199,
#   '總數': 36,
#   '行政區': '三重區'},
#  {'可借': 0,
#   '可還': 28,
#   '地址': '重陽路三段3號(民生街側)',
#   '日期時間': '2024-04-30 00:25:14',
#   '狀態': '維護中',
#   '站點名稱': '修德國小',
#   '經度': 121.49045,
#   '緯度': 25.0653,
#   '總數': 28,
#   '行政區': '三重區'},
#  {'可借': 5,
#   '可還': 52,
#   '地址': '中正北路107號(旁)',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '明志國中',
#   '經度': 121.48898,
#   '緯度': 25.0634,
#   '總數': 57,
#   '行政區': '三重區'},
#  {'可借': 6,
#   '可還': 19,
#   '地址': '龍濱路196號(對面)',
#   '日期時間': '2024-06-22 14:53:19',
#   '狀態': '營業中',
#   '站點名稱': '龍門龍濱路口',
#   '經度': 121.50098,
#   '緯度': 25.07348,
#   '總數': 26,
#   '行政區': '三重區'},
#  {'可借': 11,
#   '可還': 21,
#   '地址': '龍門路274巷35號(對面)',
#   '日期時間': '2024-06-22 14:53:20',
#   '狀態': '營業中',
#   '站點名稱': '三德公園',
#   '經度': 121.5011703780708,
#   '緯度': 25.07521510241447,
#   '總數': 33,
#   '行政區': '三重區'},
#  {'可借': 12,
#   '可還': 20,
#   '地址': '開元街58號/長元街65巷16弄對面',
#   '日期時間': '2024-06-22 14:53:20',
#   '狀態': '營業中',
#   '站點名稱': '開元市民活動中心',
#   '經度': 121.50356,
#   '緯度': 25.06607,
#   '總數': 32,
#   '行政區': '三重區'},
#  {'可借': 11,
#   '可還': 5,
#   '地址': '信義西街18號對面人行道',
#   '日期時間': '2024-06-22 14:52:19',
#   '狀態': '營業中',
#   '站點名稱': '信義公園',
#   '經度': 121.49875,
#   '緯度': 25.0648,
#   '總數': 16,
#   '行政區': '三重區'},
#  {'可借': 1,
#   '可還': 18,
#   '地址': '集成路2號至8號前人行道',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '集成成功路口',
#   '經度': 121.48821,
#   '緯度': 25.05154,
#   '總數': 19,
#   '行政區': '三重區'},
#  {'可借': 0,
#   '可還': 27,
#   '地址': '三重區中正南路251號(右側人行道)',
#   '日期時間': '2024-06-22 14:49:17',
#   '狀態': '營業中',
#   '站點名稱': '翔譽雙子星',
#   '經度': 121.49292,
#   '緯度': 25.05364,
#   '總數': 28,
#   '行政區': '三重區'},
#  {'可借': 8,
#   '可還': 20,
#   '地址': '疏洪東路三段/中正北路560巷口',
#   '日期時間': '2024-06-22 14:15:22',
#   '狀態': '營業中',
#   '站點名稱': '穀保家商',
#   '經度': 121.47103,
#   '緯度': 25.0681,
#   '總數': 28,
#   '行政區': '三重區'},
#  {'可借': 37,
#   '可還': 11,
#   '地址': '文化北路101號至119號對面',
#   '日期時間': '2024-06-22 14:44:20',
#   '狀態': '營業中',
#   '站點名稱': '正義公園',
#   '經度': 121.49782,
#   '緯度': 25.06855,
#   '總數': 48,
#   '行政區': '三重區'},
#  {'可借': 2,
#   '可還': 14,
#   '地址': '大同北路56號(對面)',
#   '日期時間': '2024-06-22 14:37:20',
#   '狀態': '營業中',
#   '站點名稱': '大智公園',
#   '經度': 121.49445,
#   '緯度': 25.06361,
#   '總數': 16,
#   '行政區': '三重區'},
#  {'可借': 9,
#   '可還': 26,
#   '地址': '仁愛街/三和路3段11巷',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '捷運三重國小站',
#   '經度': 121.49713,
#   '緯度': 25.07042,
#   '總數': 38,
#   '行政區': '三重區'},
#  {'可借': 8,
#   '可還': 16,
#   '地址': '溪尾街303號(對面公園)',
#   '日期時間': '2024-06-22 14:48:20',
#   '狀態': '營業中',
#   '站點名稱': '碧華公園',
#   '經度': 121.48749,
#   '緯度': 25.08374,
#   '總數': 24,
#   '行政區': '三重區'},
#  {'可借': 0,
#   '可還': 17,
#   '地址': '永福街197巷6之1號',
#   '日期時間': '2024-06-22 14:17:29',
#   '狀態': '營業中',
#   '站點名稱': '三重永豐公園',
#   '經度': 121.47816,
#   '緯度': 25.07463,
#   '總數': 17,
#   '行政區': '三重區'},
#  {'可借': 6,
#   '可還': 14,
#   '地址': '五谷王北街77號(後方停車場旁人行道)',
#   '日期時間': '2024-06-22 14:48:20',
#   '狀態': '營業中',
#   '站點名稱': '先嗇宮',
#   '經度': 121.47601,
#   '緯度': 25.05119,
#   '總數': 20,
#   '行政區': '三重區'},
#  {'可借': 18,
#   '可還': 6,
#   '地址': '中興北街42巷17弄8號旁',
#   '日期時間': '2024-06-22 14:49:23',
#   '狀態': '營業中',
#   '站點名稱': '中興北街42巷17弄',
#   '經度': 121.46892,
#   '緯度': 25.05006,
#   '總數': 24,
#   '行政區': '三重區'},
#  {'可借': 0,
#   '可還': 13,
#   '地址': '仁愛街584號旁公園人行道',
#   '日期時間': '2024-06-22 14:31:14',
#   '狀態': '營業中',
#   '站點名稱': '慈愛公園',
#   '經度': 121.48461,
#   '緯度': 25.08119,
#   '總數': 13,
#   '行政區': '三重區'},
#  {'可借': 7,
#   '可還': 13,
#   '地址': '仁義街258號至290號',
#   '日期時間': '2024-06-22 14:52:20',
#   '狀態': '營業中',
#   '站點名稱': '進安公園',
#   '經度': 121.49377,
#   '緯度': 25.08603,
#   '總數': 20,
#   '行政區': '三重區'},
#  {'可借': 12,
#   '可還': 16,
#   '地址': '五華街7巷59號(旁)',
#   '日期時間': '2024-06-22 14:42:20',
#   '狀態': '營業中',
#   '站點名稱': '三重五常公園',
#   '經度': 121.49615,
#   '緯度': 25.08065,
#   '總數': 28,
#   '行政區': '三重區'},
#  {'可借': 14,
#   '可還': 25,
#   '地址': '五華街66號(對面)',
#   '日期時間': '2024-06-22 14:51:21',
#   '狀態': '營業中',
#   '站點名稱': '五福里(五華街)',
#   '經度': 121.4939,
#   '緯度': 25.08173,
#   '總數': 39,
#   '行政區': '三重區'},
#  {'可借': 2,
#   '可還': 29,
#   '地址': '仁安街2號(對面)',
#   '日期時間': '2024-06-22 14:37:19',
#   '狀態': '營業中',
#   '站點名稱': '碧華公園(集勇街)',
#   '經度': 121.48554,
#   '緯度': 25.08415,
#   '總數': 32,
#   '行政區': '三重區'},
#  {'可借': 16,
#   '可還': 72,
#   '地址': '三信路1號(旁)',
#   '日期時間': '2024-06-22 14:46:21',
#   '狀態': '營業中',
#   '站點名稱': '新北高中',
#   '經度': 121.48953,
#   '緯度': 25.08723,
#   '總數': 88,
#   '行政區': '三重區'},
#  {'可借': 10,
#   '可還': 62,
#   '地址': '中正北路163號(旁)',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '三重商工',
#   '經度': 121.48071,
#   '緯度': 25.06868,
#   '總數': 72,
#   '行政區': '三重區'},
#  {'可借': 7,
#   '可還': 27,
#   '地址': '忠孝路三段75巷11號(對面)',
#   '日期時間': '2024-06-22 14:48:20',
#   '狀態': '營業中',
#   '站點名稱': '二重國中',
#   '經度': 121.48047,
#   '緯度': 25.06596,
#   '總數': 34,
#   '行政區': '三重區'},
#  {'可借': 0,
#   '可還': 27,
#   '地址': '自強路四段55號(旁)',
#   '日期時間': '2024-06-22 14:39:15',
#   '狀態': '營業中',
#   '站點名稱': '自強溪尾街口',
#   '經度': 121.49016,
#   '緯度': 25.07822,
#   '總數': 28,
#   '行政區': '三重區'},
#  {'可借': 30,
#   '可還': 27,
#   '地址': '三和路四段216號(旁)',
#   '日期時間': '2024-06-22 14:52:20',
#   '狀態': '營業中',
#   '站點名稱': '捷運三和國中站(1號出口)',
#   '經度': 121.4878,
#   '緯度': 25.07588,
#   '總數': 57,
#   '行政區': '三重區'},
#  {'可借': 14,
#   '可還': 9,
#   '地址': '車路頭街/車路頭街139巷(東南側)',
#   '日期時間': '2024-06-22 14:48:15',
#   '狀態': '營業中',
#   '站點名稱': '永盛公園',
#   '經度': 121.4843,
#   '緯度': 25.07613,
#   '總數': 23,
#   '行政區': '三重區'},
#  {'可借': 25,
#   '可還': 33,
#   '地址': '重新路五段555號(對面)',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '捷運先嗇宮站(2號出口)',
#   '經度': 121.47099,
#   '緯度': 25.04607,
#   '總數': 64,
#   '行政區': '三重區'},
#  {'可借': 18,
#   '可還': 12,
#   '地址': '興德路129號(前)',
#   '日期時間': '2024-06-22 14:25:22',
#   '狀態': '營業中',
#   '站點名稱': '藍天大樓',
#   '經度': 121.47017,
#   '緯度': 25.0531,
#   '總數': 30,
#   '行政區': '三重區'},
#  {'可借': 3,
#   '可還': 33,
#   '地址': '中興北街175巷8號(對面)',
#   '日期時間': '2024-06-22 14:39:20',
#   '狀態': '營業中',
#   '站點名稱': '中興北街175巷口',
#   '經度': 121.47133,
#   '緯度': 25.05597,
#   '總數': 36,
#   '行政區': '三重區'},
#  {'可借': 22,
#   '可還': 11,
#   '地址': '正義南路165號(對面)',
#   '日期時間': '2024-06-22 14:53:20',
#   '狀態': '營業中',
#   '站點名稱': '同安公園',
#   '經度': 121.49907,
#   '緯度': 25.05732,
#   '總數': 33,
#   '行政區': '三重區'},
#  {'可借': 8,
#   '可還': 18,
#   '地址': '忠孝路三段89號(旁)',
#   '日期時間': '2024-06-22 14:40:32',
#   '狀態': '營業中',
#   '站點名稱': '東海高中',
#   '經度': 121.47942,
#   '緯度': 25.06484,
#   '總數': 26,
#   '行政區': '三重區'},
#  {'可借': 11,
#   '可還': 27,
#   '地址': '頂崁街/忠孝路三段96巷(東北側)',
#   '日期時間': '2024-06-22 14:47:20',
#   '狀態': '營業中',
#   '站點名稱': '二重國小',
#   '經度': 121.47766,
#   '緯度': 25.06598,
#   '總數': 38,
#   '行政區': '三重區'},
#  {'可借': 28,
#   '可還': 19,
#   '地址': '自強路一段158號(旁)',
#   '日期時間': '2024-06-22 14:48:20',
#   '狀態': '營業中',
#   '站點名稱': '新北市立圖書館三重分館',
#   '經度': 121.49553,
#   '緯度': 25.0661,
#   '總數': 47,
#   '行政區': '三重區'},
#  {'可借': 2,
#   '可還': 39,
#   '地址': '公園街45號(對面)',
#   '日期時間': '2024-06-22 14:51:21',
#   '狀態': '營業中',
#   '站點名稱': '龍門公園',
#   '經度': 121.49848,
#   '緯度': 25.07482,
#   '總數': 43,
#   '行政區': '三重區'},
#  {'可借': 11,
#   '可還': 15,
#   '地址': '永福街79號(對面)',
#   '日期時間': '2024-06-22 14:53:20',
#   '狀態': '營業中',
#   '站點名稱': '永福國小',
#   '經度': 121.48032,
#   '緯度': 25.07771,
#   '總數': 26,
#   '行政區': '三重區'},
#  {'可借': 2,
#   '可還': 23,
#   '地址': '集英路67號(對面)',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '太陽公園',
#   '經度': 121.4856,
#   '緯度': 25.08645,
#   '總數': 25,
#   '行政區': '三重區'},
#  {'可借': 24,
#   '可還': 9,
#   '地址': '捷運路/捷運路37巷',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '捷運三重站(3號出口)',
#   '經度': 121.48474,
#   '緯度': 25.05588,
#   '總數': 33,
#   '行政區': '三重區'},
#  {'可借': 4,
#   '可還': 18,
#   '地址': '仁愛街112巷7號(對面)',
#   '日期時間': '2024-06-22 14:11:06',
#   '狀態': '營業中',
#   '站點名稱': '仁愛街112巷',
#   '經度': 121.49488,
#   '緯度': 25.07486,
#   '總數': 22,
#   '行政區': '三重區'},
#  {'可借': 8,
#   '可還': 16,
#   '地址': '頂文一街頂文二街口(東南側公園人行道)',
#   '日期時間': '2024-06-22 14:50:35',
#   '狀態': '營業中',
#   '站點名稱': '頂崁公園',
#   '經度': 121.4756,
#   '緯度': 25.05493,
#   '總數': 24,
#   '行政區': '三重區'},
#  {'可借': 2,
#   '可還': 23,
#   '地址': '力行路一段38巷6號(對面)',
#   '日期時間': '2024-06-22 14:50:35',
#   '狀態': '營業中',
#   '站點名稱': '重陽國小',
#   '經度': 121.48434,
#   '緯度': 25.06625,
#   '總數': 25,
#   '行政區': '三重區'},
#  {'可借': 2,
#   '可還': 18,
#   '地址': '永福街10巷8號(旁)',
#   '日期時間': '2024-06-22 14:47:20',
#   '狀態': '營業中',
#   '站點名稱': '力行地下停車場',
#   '經度': 121.48287,
#   '緯度': 25.07787,
#   '總數': 20,
#   '行政區': '三重區'},
#  {'可借': 6,
#   '可還': 12,
#   '地址': '環河北路三段/吉祥街(東南側)',
#   '日期時間': '2024-06-22 14:07:20',
#   '狀態': '營業中',
#   '站點名稱': '三重親水公園',
#   '經度': 121.49039,
#   '緯度': 25.09114,
#   '總數': 18,
#   '行政區': '三重區'},
#  {'可借': 19,
#   '可還': 13,
#   '地址': '中正北路193巷45號',
#   '日期時間': '2024-06-22 14:44:21',
#   '狀態': '營業中',
#   '站點名稱': '中正北路193巷(愛買三重店)',
#   '經度': 121.47599,
#   '緯度': 25.07136,
#   '總數': 32,
#   '行政區': '三重區'},
#  {'可借': 7,
#   '可還': 14,
#   '地址': '力行路一段183號(對面)',
#   '日期時間': '2024-06-22 14:38:20',
#   '狀態': '營業中',
#   '站點名稱': '三重商工地下停車場',
#   '經度': 121.48352,
#   '緯度': 25.06966,
#   '總數': 21,
#   '行政區': '三重區'},
#  {'可借': 16,
#   '可還': 9,
#   '地址': '新北大道一段157號(對面)',
#   '日期時間': '2024-06-22 14:45:23',
#   '狀態': '營業中',
#   '站點名稱': '三重棒球場',
#   '經度': 121.4815,
#   '緯度': 25.0613,
#   '總數': 25,
#   '行政區': '三重區'},
#  {'可借': 1,
#   '可還': 16,
#   '地址': '溪尾街196巷38號(旁)',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '溪尾街196巷/仁美街口',
#   '經度': 121.48587,
#   '緯度': 25.0802,
#   '總數': 18,
#   '行政區': '三重區'},
#  {'可借': 25,
#   '可還': 13,
#   '地址': '民生東街/安慶街149巷(西北側)',
#   '日期時間': '2024-06-22 14:53:20',
#   '狀態': '營業中',
#   '站點名稱': '六張公園',
#   '經度': 121.49405,
#   '緯度': 25.06966,
#   '總數': 38,
#   '行政區': '三重區'},
#  {'可借': 3,
#   '可還': 15,
#   '地址': '集賢路158號(旁)',
#   '日期時間': '2024-06-22 14:34:19',
#   '狀態': '營業中',
#   '站點名稱': '自然公園',
#   '經度': 121.48799,
#   '緯度': 25.08984,
#   '總數': 18,
#   '行政區': '三重區'},
#  {'可借': 0,
#   '可還': 12,
#   '地址': '三和路四段145巷81號',
#   '日期時間': '2024-06-22 14:45:16',
#   '狀態': '營業中',
#   '站點名稱': '仁美街/三和路四段145巷口',
#   '經度': 121.48636,
#   '緯度': 25.07872,
#   '總數': 12,
#   '行政區': '三重區'},
#  {'可借': 15,
#   '可還': 7,
#   '地址': '光明路67-1號南側',
#   '日期時間': '2024-06-22 14:46:21',
#   '狀態': '營業中',
#   '站點名稱': '光明市場',
#   '經度': 121.49181,
#   '緯度': 25.05734,
#   '總數': 22,
#   '行政區': '三重區'},
#  {'可借': 8,
#   '可還': 7,
#   '地址': '元富一街/仁義街79巷(東側)',
#   '日期時間': '2024-06-22 14:08:20',
#   '狀態': '營業中',
#   '站點名稱': '元富一街/仁義街79巷口',
#   '經度': 121.49955,
#   '緯度': 25.08006,
#   '總數': 15,
#   '行政區': '三重區'},
#  {'可借': 1,
#   '可還': 15,
#   '地址': '大仁街23號(對面)',
#   '日期時間': '2024-06-22 14:54:14',
#   '狀態': '營業中',
#   '站點名稱': '國隆大仁街口',
#   '經度': 121.492,
#   '緯度': 25.06468,
#   '總數': 17,
#   '行政區': '三重區'},
#  {'可借': 8,
#   '可還': 3,
#   '地址': '三和路四段141號(前)',
#   '日期時間': '2024-06-22 14:49:23',
#   '狀態': '營業中',
#   '站點名稱': '三和慈愛街口',
#   '經度': 121.48417,
#   '緯度': 25.07814,
#   '總數': 11,
#   '行政區': '三重區'},
#  {'可借': 0,
#   '可還': 11,
#   '地址': '福隆路59號(對面)',
#   '日期時間': '2024-06-22 14:50:29',
#   '狀態': '營業中',
#   '站點名稱': '三重社會福利服務中心',
#   '經度': 121.49128,
#   '緯度': 25.07781,
#   '總數': 11,
#   '行政區': '三重區'},
#  {'可借': 8,
#   '可還': 4,
#   '地址': '三和路四段109-1號(對面)',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '捷運三和國中站(2號出口)',
#   '經度': 121.48635,
#   '緯度': 25.07703,
#   '總數': 17,
#   '行政區': '三重區'},
#  {'可借': 9,
#   '可還': 9,
#   '地址': '三和路三段61號(前)',
#   '日期時間': '2024-06-22 14:46:21',
#   '狀態': '營業中',
#   '站點名稱': '三和龍門路口',
#   '經度': 121.4949,
#   '緯度': 25.0718,
#   '總數': 18,
#   '行政區': '三重區'},
#  {'可借': 1,
#   '可還': 19,
#   '地址': '仁愛街190號(對面)',
#   '日期時間': '2024-06-22 14:51:21',
#   '狀態': '營業中',
#   '站點名稱': '元信二仁愛街口',
#   '經度': 121.49417,
#   '緯度': 25.07709,
#   '總數': 20,
#   '行政區': '三重區'},
#  {'可借': 4,
#   '可還': 9,
#   '地址': '力行路二段93號(前)',
#   '日期時間': '2024-06-22 14:51:21',
#   '狀態': '營業中',
#   '站點名稱': '力行路二段91巷口',
#   '經度': 121.48255,
#   '緯度': 25.07583,
#   '總數': 13,
#   '行政區': '三重區'},
#  {'可借': 12,
#   '可還': 10,
#   '地址': '永福街72巷23號(對面)',
#   '日期時間': '2024-06-22 14:43:20',
#   '狀態': '營業中',
#   '站點名稱': '永福國小(永福街72巷)',
#   '經度': 121.47985,
#   '緯度': 25.07657,
#   '總數': 22,
#   '行政區': '三重區'},
#  {'可借': 16,
#   '可還': 8,
#   '地址': '大智街260號(前)',
#   '日期時間': '2024-06-22 14:13:19',
#   '狀態': '營業中',
#   '站點名稱': '格致中學',
#   '經度': 121.48907,
#   '緯度': 25.07403,
#   '總數': 24,
#   '行政區': '三重區'},
#  {'可借': 4,
#   '可還': 11,
#   '地址': '重新路一段43號(旁)',
#   '日期時間': '2024-06-22 14:42:20',
#   '狀態': '營業中',
#   '站點名稱': '三重派出所',
#   '經度': 121.5023,
#   '緯度': 25.06395,
#   '總數': 15,
#   '行政區': '三重區'},
#  {'可借': 1,
#   '可還': 13,
#   '地址': '環河北路三段/集賢路(西北側)',
#   '日期時間': '2024-06-22 14:22:20',
#   '狀態': '營業中',
#   '站點名稱': '重陽橋市民活動中心',
#   '經度': 121.49602,
#   '緯度': 25.08634,
#   '總數': 15,
#   '行政區': '三重區'},
#  {'可借': 5,
#   '可還': 15,
#   '地址': '大有街12-1號旁',
#   '日期時間': '2024-06-22 14:37:20',
#   '狀態': '營業中',
#   '站點名稱': '二重埔市民活動中心',
#   '經度': 121.47557,
#   '緯度': 25.06675,
#   '總數': 20,
#   '行政區': '三重區'},
#  {'可借': 10,
#   '可還': 3,
#   '地址': '光復路二段87巷10-12號(旁)',
#   '日期時間': '2024-06-22 10:54:20',
#   '狀態': '營業中',
#   '站點名稱': '神農街/光復路二段129巷口',
#   '經度': 121.47409,
#   '緯度': 25.05899,
#   '總數': 14,
#   '行政區': '三重區'},
#  {'可借': 10,
#   '可還': 10,
#   '地址': '秀江街107號(對面)',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '光榮國中(秀江街)',
#   '經度': 121.49994,
#   '緯度': 25.07221,
#   '總數': 20,
#   '行政區': '三重區'},
#  {'可借': 23,
#   '可還': 17,
#   '地址': '神農路/興德路(東南側)',
#   '日期時間': '2024-06-22 14:54:19',
#   '狀態': '營業中',
#   '站點名稱': '神農興德路口(恆美社區)',
#   '經度': 121.47427,
#   '緯度': 25.05333,
#   '總數': 40,
#   '行政區': '三重區'},
#  {'可借': 4,
#   '可還': 9,
#   '地址': '大智街22號(對面)',
#   '日期時間': '2024-06-22 14:46:20',
#   '狀態': '營業中',
#   '站點名稱': '正義國小地下停車場',
#   '經度': 121.49491,
#   '緯度': 25.06492,
#   '總數': 13,
#   '行政區': '三重區'},
#  {'可借': 6,
#   '可還': 8,
#   '地址': '頂文路/神農街(西北側)',
#   '日期時間': '2024-06-22 14:52:19',
#   '狀態': '營業中',
#   '站點名稱': '群光公園',
#   '經度': 121.47404,
#   '緯度': 25.05604,
#   '總數': 15,
#   '行政區': '三重區'},
#  {'可借': 0,
#   '可還': 12,
#   '地址': '元信二街/元信二街202巷(東南側)',
#   '日期時間': '2024-06-22 14:50:29',
#   '狀態': '營業中',
#   '站點名稱': '仁信段平面停車場',
#   '經度': 121.49629,
#   '緯度': 25.07914,
#   '總數': 12,
#   '行政區': '三重區'},
#  {'可借': 13,
#   '可還': 27,
#   '地址': '中正北路29號',
#   '日期時間': '2024-06-22 14:39:21',
#   '狀態': '營業中',
#   '站點名稱': '中正北路25巷(交響院社區)',
#   '經度': 121.49185,
#   '緯度': 25.06318,
#   '總數': 40,
#   '行政區': '三重區'},
#  {'可借': 8,
#   '可還': 5,
#   '地址': '神農街/五谷王北街42巷(東北側)',
#   '日期時間': '2024-06-22 14:05:23',
#   '狀態': '營業中',
#   '站點名稱': '興穀國小',
#   '經度': 121.47421,
#   '緯度': 25.04937,
#   '總數': 15,
#   '行政區': '三重區'},
#  {'可借': 5,
#   '可還': 12,
#   '地址': '興德路55號南側',
#   '日期時間': '2024-06-22 12:45:22',
#   '狀態': '營業中',
#   '站點名稱': '三重區停八停車場',
#   '經度': 121.47621,
#   '緯度': 25.05365,
#   '總數': 17,
#   '行政區': '三重區'},
#  {'可借': 2,
#   '可還': 18,
#   '地址': '國道路一段39巷1號對面',
#   '日期時間': '2024-06-22 14:51:20',
#   '狀態': '營業中',
#   '站點名稱': '國道車路頭街口',
#   '經度': 121.48424,
#   '緯度': 25.07307,
#   '總數': 20,
#   '行政區': '三重區'},
#  {'可借': 12,
#   '可還': 5,
#   '地址': '仁愛街423-1號對面',
#   '日期時間': '2024-06-22 14:35:23',
#   '狀態': '營業中',
#   '站點名稱': '仁愛街422巷口',
#   '經度': 121.49026,
#   '緯度': 25.08153,
#   '總數': 17,
#   '行政區': '三重區'},
#  {'可借': 6,
#   '可還': 8,
#   '地址': '重新路五段/重新路五段317巷(東南側)',
#   '日期時間': '2024-06-22 14:22:51',
#   '狀態': '營業中',
#   '站點名稱': '德厚公園',
#   '經度': 121.47809,
#   '緯度': 25.04883,
#   '總數': 15,
#   '行政區': '三重區'},
#  {'可借': 8,
#   '可還': 12,
#   '地址': '永德街37號(對側)',
#   '日期時間': '2024-06-22 13:29:19',
#   '狀態': '營業中',
#   '站點名稱': '永德市民活動中心',
#   '經度': 121.48842,
#   '緯度': 25.07285,
#   '總數': 20,
#   '行政區': '三重區'},
#  {'可借': 2,
#   '可還': 12,
#   '地址': '秀江街28號(對面)',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '龍濱公園',
#   '經度': 121.50218,
#   '緯度': 25.07298,
#   '總數': 14,
#   '行政區': '三重區'},
#  {'可借': 13,
#   '可還': 26,
#   '地址': '簡仔舍街',
#   '日期時間': '2024-06-22 14:17:35',
#   '狀態': '營業中',
#   '站點名稱': '簡仔舍街(河家歡社區)',
#   '經度': 121.48652,
#   '緯度': 25.05138,
#   '總數': 40,
#   '行政區': '三重區'},
#  {'可借': 12,
#   '可還': 17,
#   '地址': '三賢街101號(對面)',
#   '日期時間': '2024-06-22 14:52:20',
#   '狀態': '營業中',
#   '站點名稱': '碧華國中(三賢街)',
#   '經度': 121.48832,
#   '緯度': 25.08861,
#   '總數': 30,
#   '行政區': '三重區'},
#  {'可借': 11,
#   '可還': 4,
#   '地址': '溪尾街12號旁(國道橋下)',
#   '日期時間': '2024-06-22 14:47:20',
#   '狀態': '營業中',
#   '站點名稱': '溪尾街(國道橋下)',
#   '經度': 121.49151,
#   '緯度': 25.07486,
#   '總數': 15,
#   '行政區': '三重區'},
#  {'可借': 8,
#   '可還': 12,
#   '地址': '興德路134號(前)',
#   '日期時間': '2024-06-22 13:45:22',
#   '狀態': '營業中',
#   '站點名稱': '興德路134號(前)',
#   '經度': 121.47102,
#   '緯度': 25.05287,
#   '總數': 20,
#   '行政區': '三重區'},
#  {'可借': 12,
#   '可還': 9,
#   '地址': '自強路五段89號(對面)',
#   '日期時間': '2024-06-22 14:03:20',
#   '狀態': '營業中',
#   '站點名稱': '自強臨時平面停車場',
#   '經度': 121.49515,
#   '緯度': 25.08229,
#   '總數': 21,
#   '行政區': '三重區'},
#  {'可借': 5,
#   '可還': 12,
#   '地址': '元富二街2-20號(對面)',
#   '日期時間': '2024-06-22 14:49:23',
#   '狀態': '營業中',
#   '站點名稱': '仁義街26巷',
#   '經度': 121.49811,
#   '緯度': 25.0774,
#   '總數': 17,
#   '行政區': '三重區'},
#  {'可借': 5,
#   '可還': 16,
#   '地址': '中正北路42號(對面)',
#   '日期時間': '2024-06-22 14:09:21',
#   '狀態': '營業中',
#   '站點名稱': '中正北重陽路口',
#   '經度': 121.48736,
#   '緯度': 25.06417,
#   '總數': 21,
#   '行政區': '三重區'},
#  {'可借': 9,
#   '可還': 8,
#   '地址': '光復路一段19號(前)',
#   '日期時間': '2024-06-22 14:14:19',
#   '狀態': '營業中',
#   '站點名稱': '光復路一段15巷口',
#   '經度': 121.47213,
#   '緯度': 25.04751,
#   '總數': 17,
#   '行政區': '三重區'},
#  {'可借': 4,
#   '可還': 14,
#   '地址': '光復路一段101號(前)',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '光復路一段99巷口',
#   '經度': 121.47209,
#   '緯度': 25.05109,
#   '總數': 18,
#   '行政區': '三重區'},
#  {'可借': 8,
#   '可還': 10,
#   '地址': '光復路一段121號(前)',
#   '日期時間': '2024-06-22 14:10:30',
#   '狀態': '營業中',
#   '站點名稱': '光復興德路口(東南側)',
#   '經度': 121.4721,
#   '緯度': 25.05251,
#   '總數': 18,
#   '行政區': '三重區'},
#  {'可借': 9,
#   '可還': 7,
#   '地址': '光復路二段30號(前)',
#   '日期時間': '2024-06-22 14:28:19',
#   '狀態': '營業中',
#   '站點名稱': '光復路二段42巷口',
#   '經度': 121.47203,
#   '緯度': 25.05452,
#   '總數': 18,
#   '行政區': '三重區'},
#  {'可借': 12,
#   '可還': 6,
#   '地址': '光復路二段74號(前)',
#   '日期時間': '2024-06-22 13:21:19',
#   '狀態': '營業中',
#   '站點名稱': '光復中興北街175巷口(西北側)',
#   '經度': 121.47205,
#   '緯度': 25.05676,
#   '總數': 18,
#   '行政區': '三重區'},
#  {'可借': 13,
#   '可還': 2,
#   '地址': '集美街18號(前)',
#   '日期時間': '2024-06-22 14:53:20',
#   '狀態': '營業中',
#   '站點名稱': '集美街58巷口(東北側)',
#   '經度': 121.48833,
#   '緯度': 25.055,
#   '總數': 16,
#   '行政區': '三重區'},
#  {'可借': 7,
#   '可還': 8,
#   '地址': '三和路四段73號(旁)',
#   '日期時間': '2024-06-22 12:10:30',
#   '狀態': '營業中',
#   '站點名稱': '三和路四段73號旁',
#   '經度': 121.48977,
#   '緯度': 25.07513,
#   '總數': 15,
#   '行政區': '三重區'},
#  {'可借': 1,
#   '可還': 12,
#   '地址': '集英路1-15號(旁)',
#   '日期時間': '2024-06-22 14:24:20',
#   '狀態': '營業中',
#   '站點名稱': '三信集英路口',
#   '經度': 121.48748,
#   '緯度': 25.08563,
#   '總數': 13,
#   '行政區': '三重區'},
#  {'可借': 6,
#   '可還': 10,
#   '地址': '溪尾街327號(旁)',
#   '日期時間': '2024-06-22 14:24:19',
#   '狀態': '營業中',
#   '站點名稱': '慈化公園',
#   '經度': 121.48864,
#   '緯度': 25.08461,
#   '總數': 16,
#   '行政區': '三重區'},
#  {'可借': 6,
#   '可還': 15,
#   '地址': '三張街87號(對面)',
#   '日期時間': '2024-06-22 14:15:22',
#   '狀態': '營業中',
#   '站點名稱': '三張地下停車場',
#   '經度': 121.48981,
#   '緯度': 25.07054,
#   '總數': 22,
#   '行政區': '三重區'},
#  {'可借': 8,
#   '可還': 7,
#   '地址': '仁愛街/仁和街口',
#   '日期時間': '2024-06-22 14:29:20',
#   '狀態': '營業中',
#   '站點名稱': '仁愛仁和街口',
#   '經度': 121.49569,
#   '緯度': 25.07354,
#   '總數': 15,
#   '行政區': '三重區'},
#  {'可借': 17,
#   '可還': 33,
#   '地址': '復興路399號東北側',
#   '日期時間': '2024-06-22 14:42:20',
#   '狀態': '營業中',
#   '站點名稱': '恩主公醫院',
#   '經度': 121.36355,
#   '緯度': 24.93891,
#   '總數': 50,
#   '行政區': '三峽區'},
#  {'可借': 11,
#   '可還': 9,
#   '地址': '中華路42號',
#   '日期時間': '2024-06-22 14:49:23',
#   '狀態': '營業中',
#   '站點名稱': '安溪國小',
#   '經度': 121.37265,
#   '緯度': 24.93122,
#   '總數': 22,
#   '行政區': '三峽區'},
#  {'可借': 7,
#   '可還': 14,
#   '地址': '大同路1號(北側)',
#   '日期時間': '2024-06-22 14:22:56',
#   '狀態': '營業中',
#   '站點名稱': '介壽國小',
#   '經度': 121.37912,
#   '緯度': 24.93026,
#   '總數': 21,
#   '行政區': '三峽區'},
#  {'可借': 6,
#   '可還': 10,
#   '地址': '大同路135號(西側)',
#   '日期時間': '2024-06-22 14:44:21',
#   '狀態': '營業中',
#   '站點名稱': '安溪國中',
#   '經度': 121.37185,
#   '緯度': 24.92638,
#   '總數': 16,
#   '行政區': '三峽區'},
#  {'可借': 8,
#   '可還': 8,
#   '地址': '三樹路5號西北側',
#   '日期時間': '2024-06-22 13:40:32',
#   '狀態': '營業中',
#   '站點名稱': '三峽國光青年社會住宅',
#   '經度': 121.37686,
#   '緯度': 24.93743,
#   '總數': 16,
#   '行政區': '三峽區'},
#  {'可借': 1,
#   '可還': 27,
#   '地址': '民權街36號南側',
#   '日期時間': '2024-06-22 14:34:18',
#   '狀態': '營業中',
#   '站點名稱': '三峽區公所(三峽老街)',
#   '經度': 121.36929,
#   '緯度': 24.9339,
#   '總數': 28,
#   '行政區': '三峽區'},
#  {'可借': 8,
#   '可還': 7,
#   '地址': '弘園街22號',
#   '日期時間': '2024-06-22 14:17:34',
#   '狀態': '營業中',
#   '站點名稱': '中園國小',
#   '經度': 121.36752,
#   '緯度': 24.92785,
#   '總數': 16,
#   '行政區': '三峽區'},
#  {'可借': 8,
#   '可還': 11,
#   '地址': '復興路45號(前)',
#   '日期時間': '2024-06-22 14:49:23',
#   '狀態': '營業中',
#   '站點名稱': '復興民生街口',
#   '經度': 121.373,
#   '緯度': 24.937,
#   '總數': 20,
#   '行政區': '三峽區'},
#  {'可借': 4,
#   '可還': 25,
#   '地址': '復興路238號(前人行道)',
#   '日期時間': '2024-06-22 14:37:20',
#   '狀態': '營業中',
#   '站點名稱': '三峽國中',
#   '經度': 121.369,
#   '緯度': 24.9389,
#   '總數': 29,
#   '行政區': '三峽區'},
#  {'可借': 4,
#   '可還': 15,
#   '地址': '大義路277號',
#   '日期時間': '2024-06-22 14:40:32',
#   '狀態': '營業中',
#   '站點名稱': '海洋公園',
#   '經度': 121.37676,
#   '緯度': 24.94776,
#   '總數': 19,
#   '行政區': '三峽區'},
#  {'可借': 21,
#   '可還': 9,
#   '地址': '大學路47號對側',
#   '日期時間': '2024-06-22 14:42:20',
#   '狀態': '營業中',
#   '站點名稱': '龍埔國小',
#   '經度': 121.37676,
#   '緯度': 24.94104,
#   '總數': 30,
#   '行政區': '三峽區'},
#  {'可借': 24,
#   '可還': 34,
#   '地址': '大學路160號(對側)',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '國立臺北大學(三峽校區)',
#   '經度': 121.3729,
#   '緯度': 24.94594,
#   '總數': 58,
#   '行政區': '三峽區'},
#  {'可借': 9,
#   '可還': 8,
#   '地址': '文化路210巷15號(對面)',
#   '日期時間': '2024-06-22 14:53:19',
#   '狀態': '營業中',
#   '站點名稱': '三鶯國民運動中心',
#   '經度': 121.36858,
#   '緯度': 24.93697,
#   '總數': 17,
#   '行政區': '三峽區'},
#  {'可借': 24,
#   '可還': 26,
#   '地址': '圖資大道/法政路口(東南側)',
#   '日期時間': '2024-06-22 14:52:20',
#   '狀態': '營業中',
#   '站點名稱': '臺北大學(音律資訊大樓)',
#   '經度': 121.36992,
#   '緯度': 24.94278,
#   '總數': 50,
#   '行政區': '三峽區'},
#  {'可借': 8,
#   '可還': 14,
#   '地址': '大學路151號(台北大學體育館前)',
#   '日期時間': '2024-06-22 14:50:35',
#   '狀態': '營業中',
#   '站點名稱': '臺北大學體育館',
#   '經度': 121.36688,
#   '緯度': 24.93974,
#   '總數': 22,
#   '行政區': '三峽區'},
#  {'可借': 0,
#   '可還': 10,
#   '地址': '愛國路71號(旁)',
#   '日期時間': '2024-06-22 14:41:14',
#   '狀態': '營業中',
#   '站點名稱': '中華愛國路口',
#   '經度': 121.37462,
#   '緯度': 24.9327,
#   '總數': 10,
#   '行政區': '三峽區'},
#  {'可借': 7,
#   '可還': 7,
#   '地址': '中正路3段1號(前)',
#   '日期時間': '2024-06-21 16:42:20',
#   '狀態': '營業中',
#   '站點名稱': '中山科學研究院',
#   '經度': 121.35512,
#   '緯度': 24.90328,
#   '總數': 14,
#   '行政區': '三峽區'},
#  {'可借': 8,
#   '可還': 5,
#   '地址': '大義路195號(東南側公車站旁)',
#   '日期時間': '2024-06-22 14:46:21',
#   '狀態': '營業中',
#   '站點名稱': '學成大義路口(學成路一)',
#   '經度': 121.37803,
#   '緯度': 24.94477,
#   '總數': 13,
#   '行政區': '三峽區'},
#  {'可借': 16,
#   '可還': 6,
#   '地址': '三樹路98巷175號(旁)',
#   '日期時間': '2024-06-22 10:28:20',
#   '狀態': '營業中',
#   '站點名稱': '龍埔三樹路98巷口',
#   '經度': 121.38393,
#   '緯度': 24.93989,
#   '總數': 22,
#   '行政區': '三峽區'},
#  {'可借': 8,
#   '可還': 8,
#   '地址': '光明路96-100號對面',
#   '日期時間': '2024-06-22 14:33:20',
#   '狀態': '營業中',
#   '站點名稱': '三峽區礁溪行政中心',
#   '經度': 121.37592,
#   '緯度': 24.92843,
#   '總數': 16,
#   '行政區': '三峽區'},
#  {'可借': 15,
#   '可還': 2,
#   '地址': '隆恩街239號(前人行道)',
#   '日期時間': '2024-06-22 14:53:20',
#   '狀態': '營業中',
#   '站點名稱': '新北市客家文化園區',
#   '經度': 121.36034,
#   '緯度': 24.94207,
#   '總數': 17,
#   '行政區': '三峽區'},
#  {'可借': 11,
#   '可還': 10,
#   '地址': '國際一街90號南側',
#   '日期時間': '2024-06-22 14:12:20',
#   '狀態': '營業中',
#   '站點名稱': '龍恩公園',
#   '經度': 121.37052,
#   '緯度': 24.94135,
#   '總數': 21,
#   '行政區': '三峽區'},
#  {'可借': 5,
#   '可還': 18,
#   '地址': '國光街73號(對面)',
#   '日期時間': '2024-06-22 14:52:20',
#   '狀態': '營業中',
#   '站點名稱': '龍埔公園',
#   '經度': 121.3742,
#   '緯度': 24.93841,
#   '總數': 23,
#   '行政區': '三峽區'},
#  {'可借': 4,
#   '可還': 16,
#   '地址': '大智路25號(前)',
#   '日期時間': '2024-06-22 14:53:20',
#   '狀態': '營業中',
#   '站點名稱': '大智中山路口',
#   '經度': 121.36084,
#   '緯度': 24.93782,
#   '總數': 20,
#   '行政區': '三峽區'},
#  {'可借': 7,
#   '可還': 18,
#   '地址': '中正路二段399號(西北側)',
#   '日期時間': '2024-06-22 12:37:20',
#   '狀態': '營業中',
#   '站點名稱': '明德高中',
#   '經度': 121.36472,
#   '緯度': 24.90742,
#   '總數': 27,
#   '行政區': '三峽區'},
#  {'可借': 0,
#   '可還': 18,
#   '地址': '學府路6號',
#   '日期時間': '2024-06-22 14:53:20',
#   '狀態': '營業中',
#   '站點名稱': '學府大學路口',
#   '經度': 121.3718,
#   '緯度': 24.94779,
#   '總數': 18,
#   '行政區': '三峽區'},
#  {'可借': 2,
#   '可還': 10,
#   '地址': '大德路493號北側',
#   '日期時間': '2024-06-22 14:35:23',
#   '狀態': '營業中',
#   '站點名稱': '學府大德路口',
#   '經度': 121.37362,
#   '緯度': 24.94864,
#   '總數': 12,
#   '行政區': '三峽區'},
#  {'可借': 2,
#   '可還': 13,
#   '地址': '學勤路105號',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '大德學勤路口',
#   '經度': 121.37506,
#   '緯度': 24.94634,
#   '總數': 15,
#   '行政區': '三峽區'},
#  {'可借': 6,
#   '可還': 9,
#   '地址': '學勤路86號',
#   '日期時間': '2024-06-22 14:43:20',
#   '狀態': '營業中',
#   '站點名稱': '學勤大觀路口',
#   '經度': 121.3743,
#   '緯度': 24.94584,
#   '總數': 15,
#   '行政區': '三峽區'},
#  {'可借': 0,
#   '可還': 13,
#   '地址': '學成路278號',
#   '日期時間': '2024-06-22 14:53:19',
#   '狀態': '營業中',
#   '站點名稱': '學成大德路口',
#   '經度': 121.37634,
#   '緯度': 24.94334,
#   '總數': 13,
#   '行政區': '三峽區'},
#  {'可借': 3,
#   '可還': 12,
#   '地址': '三樹路197號',
#   '日期時間': '2024-06-22 14:46:21',
#   '狀態': '營業中',
#   '站點名稱': '三樹大德路口',
#   '經度': 121.37871,
#   '緯度': 24.94163,
#   '總數': 15,
#   '行政區': '三峽區'},
#  {'可借': 5,
#   '可還': 9,
#   '地址': '大義路7號',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '大義三樹路口',
#   '經度': 121.37899,
#   '緯度': 24.94357,
#   '總數': 14,
#   '行政區': '三峽區'},
#  {'可借': 11,
#   '可還': 8,
#   '地址': '民權街209號',
#   '日期時間': '2024-06-22 14:03:20',
#   '狀態': '營業中',
#   '站點名稱': '中園國小(民權街)',
#   '經度': 121.36767,
#   '緯度': 24.92853,
#   '總數': 19,
#   '行政區': '三峽區'},
#  {'可借': 4,
#   '可還': 17,
#   '地址': '中山路16號',
#   '日期時間': '2024-06-22 13:45:22',
#   '狀態': '營業中',
#   '站點名稱': '三峽國小(中山路)',
#   '經度': 121.36779,
#   '緯度': 24.93474,
#   '總數': 21,
#   '行政區': '三峽區'},
#  {'可借': 15,
#   '可還': 5,
#   '地址': '學成路3號',
#   '日期時間': '2024-06-22 14:53:20',
#   '狀態': '營業中',
#   '站點名稱': '臺北大學宿舍(學成路)',
#   '經度': 121.36856,
#   '緯度': 24.94092,
#   '總數': 20,
#   '行政區': '三峽區'},
#  {'可借': 11,
#   '可還': 4,
#   '地址': '國際二街33號',
#   '日期時間': '2024-06-22 14:47:20',
#   '狀態': '營業中',
#   '站點名稱': '國際二國學街口',
#   '經度': 121.37233,
#   '緯度': 24.94319,
#   '總數': 15,
#   '行政區': '三峽區'},
#  {'可借': 6,
#   '可還': 4,
#   '地址': '大學路113號',
#   '日期時間': '2024-06-22 14:45:23',
#   '狀態': '營業中',
#   '站點名稱': '大學學成路口',
#   '經度': 121.37521,
#   '緯度': 24.94298,
#   '總數': 11,
#   '行政區': '三峽區'},
#  {'可借': 2,
#   '可還': 18,
#   '地址': '國慶路2號',
#   '日期時間': '2024-06-22 14:42:20',
#   '狀態': '營業中',
#   '站點名稱': '國慶三樹路口',
#   '經度': 121.37738,
#   '緯度': 24.93826,
#   '總數': 20,
#   '行政區': '三峽區'},
#  {'可借': 12,
#   '可還': 1,
#   '地址': '三樹路69號',
#   '日期時間': '2024-06-22 14:50:29',
#   '狀態': '營業中',
#   '站點名稱': '三樹大學路口',
#   '經度': 121.37816,
#   '緯度': 24.93951,
#   '總數': 14,
#   '行政區': '三峽區'},
#  {'可借': 11,
#   '可還': 8,
#   '地址': '二鬮路136巷49號北側',
#   '日期時間': '2024-06-22 10:53:20',
#   '狀態': '營業中',
#   '站點名稱': '薇多綠雅社區(警衛亭)',
#   '經度': 121.35816,
#   '緯度': 24.90883,
#   '總數': 19,
#   '行政區': '三峽區'},
#  {'可借': 5,
#   '可還': 10,
#   '地址': '二鬮路136巷73號北側',
#   '日期時間': '2024-06-22 09:56:20',
#   '狀態': '營業中',
#   '站點名稱': '薇多綠雅社區(活動中心)',
#   '經度': 121.35727,
#   '緯度': 24.90955,
#   '總數': 15,
#   '行政區': '三峽區'},
#  {'可借': 9,
#   '可還': 11,
#   '地址': '溪東路218巷3號前',
#   '日期時間': '2024-06-22 14:27:20',
#   '狀態': '營業中',
#   '站點名稱': '溪東市民活動中心',
#   '經度': 121.40753,
#   '緯度': 24.93192,
#   '總數': 20,
#   '行政區': '三峽區'},
#  {'可借': 6,
#   '可還': 4,
#   '地址': '光明路69巷37號',
#   '日期時間': '2024-06-22 14:53:19',
#   '狀態': '營業中',
#   '站點名稱': '光明路69巷口',
#   '經度': 121.37726,
#   '緯度': 24.92918,
#   '總數': 10,
#   '行政區': '三峽區'},
#  {'可借': 0,
#   '可還': 15,
#   '地址': '大同路268號對側',
#   '日期時間': '2024-06-22 14:52:15',
#   '狀態': '營業中',
#   '站點名稱': '大同路270巷口',
#   '經度': 121.36551,
#   '緯度': 24.92526,
#   '總數': 15,
#   '行政區': '三峽區'},
#  {'可借': 7,
#   '可還': 11,
#   '地址': '民生街1巷5-82號',
#   '日期時間': '2024-06-22 13:56:20',
#   '狀態': '營業中',
#   '站點名稱': '龍埔自行車道(民生街1巷)',
#   '經度': 121.37824,
#   '緯度': 24.93455,
#   '總數': 20,
#   '行政區': '三峽區'},
#  {'可借': 15,
#   '可還': 1,
#   '地址': '介壽路二段25號東側',
#   '日期時間': '2024-06-22 14:41:20',
#   '狀態': '營業中',
#   '站點名稱': '龍埔介壽路口',
#   '經度': 121.39008,
#   '緯度': 24.93513,
#   '總數': 16,
#   '行政區': '三峽區'},
#  {'可借': 2,
#   '可還': 7,
#   '地址': '學成路216號(南側)',
#   '日期時間': '2024-06-22 14:29:20',
#   '狀態': '營業中',
#   '站點名稱': '國慶學成路口',
#   '經度': 121.37397,
#   '緯度': 24.94095,
#   '總數': 10,
#   '行政區': '三峽區'},
#  {'可借': 9,
#   '可還': 6,
#   '地址': '中園街124號(旁)',
#   '日期時間': '2024-06-22 12:16:21',
#   '狀態': '營業中',
#   '站點名稱': '中園街福隆宮',
#   '經度': 121.36717,
#   '緯度': 24.92239,
#   '總數': 15,
#   '行政區': '三峽區'},
#  {'可借': 16,
#   '可還': 8,
#   '地址': '臺北大學蓮池',
#   '日期時間': '2024-06-22 13:22:20',
#   '狀態': '營業中',
#   '站點名稱': '臺北大學蓮池',
#   '經度': 121.37117,
#   '緯度': 24.94723,
#   '總數': 24,
#   '行政區': '三峽區'},
#  {'可借': 3,
#   '可還': 8,
#   '地址': '尋鳶大道/中央大道(西北側)',
#   '日期時間': '2024-06-22 13:52:20',
#   '狀態': '營業中',
#   '站點名稱': '臺北大學商學院(尋鳶大道)',
#   '經度': 121.37249,
#   '緯度': 24.94557,
#   '總數': 11,
#   '行政區': '三峽區'},
#  {'可借': 10,
#   '可還': 16,
#   '地址': '法商大道/中央大道(東北側)',
#   '日期時間': '2024-06-22 14:43:19',
#   '狀態': '營業中',
#   '站點名稱': '臺北大學商學院(法商大道)',
#   '經度': 121.37146,
#   '緯度': 24.94499,
#   '總數': 26,
#   '行政區': '三峽區'},
#  {'可借': 11,
#   '可還': 12,
#   '地址': '法商大道/中央大道(西北側)',
#   '日期時間': '2024-06-22 12:18:20',
#   '狀態': '營業中',
#   '站點名稱': '臺北大學行政大樓(法商大道)',
#   '經度': 121.3712,
#   '緯度': 24.94494,
#   '總數': 23,
#   '行政區': '三峽區'},
#  {'可借': 15,
#   '可還': 14,
#   '地址': '臺北大學法學院(鳶飛大道)',
#   '日期時間': '2024-06-22 11:56:19',
#   '狀態': '營業中',
#   '站點名稱': '臺北大學法學院(鳶飛大道)',
#   '經度': 121.37333,
#   '緯度': 24.94438,
#   '總數': 29,
#   '行政區': '三峽區'},
#  {'可借': 3,
#   '可還': 19,
#   '地址': '臺北大學公共事務大樓(法商大道)',
#   '日期時間': '2024-06-22 13:07:19',
#   '狀態': '營業中',
#   '站點名稱': '臺北大學公共事務大樓(法商大道)',
#   '經度': 121.37212,
#   '緯度': 24.94363,
#   '總數': 22,
#   '行政區': '三峽區'},
#  {'可借': 10,
#   '可還': 13,
#   '地址': '臺北大學公共事務大樓(公政大道)',
#   '日期時間': '2024-06-22 14:45:22',
#   '狀態': '營業中',
#   '站點名稱': '臺北大學公共事務大樓(公政大道)',
#   '經度': 121.37121,
#   '緯度': 24.94325,
#   '總數': 23,
#   '行政區': '三峽區'},
#  {'可借': 8,
#   '可還': 26,
#   '地址': '公政大道/中央大道(東北側)',
#   '日期時間': '2024-06-22 14:49:23',
#   '狀態': '營業中',
#   '站點名稱': '臺北大學行政大樓(公政大道)',
#   '經度': 121.37037,
#   '緯度': 24.94457,
#   '總數': 34,
#   '行政區': '三峽區'},
#  {'可借': 8,
#   '可還': 17,
#   '地址': '公政大道/中央大道(西北側)',
#   '日期時間': '2024-06-22 14:38:19',
#   '狀態': '營業中',
#   '站點名稱': '臺北大學社科院(公政大道)',
#   '經度': 121.3701,
#   '緯度': 24.94441,
#   '總數': 25,
#   '行政區': '三峽區'},
#  {'可借': 12,
#   '可還': 15,
#   '地址': '臺北大學社科院(圖資大道)',
#   '日期時間': '2024-06-22 12:52:20',
#   '狀態': '營業中',
#   '站點名稱': '臺北大學社科院(圖資大道)',
#   '經度': 121.36912,
#   '緯度': 24.94396,
#   '總數': 27,
#   '行政區': '三峽區'},
#  {'可借': 16,
#   '可還': 14,
#   '地址': '臺北大學田徑場(體風路)',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '臺北大學田徑場(體風路)',
#   '經度': 121.36433,
#   '緯度': 24.9395,
#   '總數': 30,
#   '行政區': '三峽區'},
#  {'可借': 9,
#   '可還': 6,
#   '地址': '臺北大學隆恩哨(忘憂路)',
#   '日期時間': '2024-06-22 12:49:20',
#   '狀態': '營業中',
#   '站點名稱': '臺北大學隆恩哨(忘憂路)',
#   '經度': 121.36547,
#   '緯度': 24.94254,
#   '總數': 15,
#   '行政區': '三峽區'},
#  {'可借': 8,
#   '可還': 6,
#   '地址': '臺北大學懷德居木師基地',
#   '日期時間': '2024-06-22 13:32:10',
#   '狀態': '營業中',
#   '站點名稱': '臺北大學懷德居木師基地',
#   '經度': 121.36743,
#   '緯度': 24.94334,
#   '總數': 14,
#   '行政區': '三峽區'},
#  {'可借': 10,
#   '可還': 13,
#   '地址': '大義路277號(北側)',
#   '日期時間': '2024-06-22 14:44:21',
#   '狀態': '營業中',
#   '站點名稱': '北大高中',
#   '經度': 121.37505,
#   '緯度': 24.9492,
#   '總數': 23,
#   '行政區': '三峽區'},
#  {'可借': 5,
#   '可還': 10,
#   '地址': '光明路/愛國路(東側停車場內)',
#   '日期時間': '2024-06-22 14:52:19',
#   '狀態': '營業中',
#   '站點名稱': '光明停車場',
#   '經度': 121.3741,
#   '緯度': 24.93036,
#   '總數': 15,
#   '行政區': '三峽區'},
#  {'可借': 1,
#   '可還': 9,
#   '地址': '中園街13號(清水街側)',
#   '日期時間': '2024-06-22 14:29:15',
#   '狀態': '營業中',
#   '站點名稱': '八安大橋(清水街)',
#   '經度': 121.36891,
#   '緯度': 24.92701,
#   '總數': 10,
#   '行政區': '三峽區'},
#  {'可借': 4,
#   '可還': 11,
#   '地址': '文化路/中山路口(西南側)',
#   '日期時間': '2024-06-22 14:50:35',
#   '狀態': '營業中',
#   '站點名稱': '三峽中山公園',
#   '經度': 121.36584,
#   '緯度': 24.93561,
#   '總數': 15,
#   '行政區': '三峽區'},
#  {'可借': 18,
#   '可還': 4,
#   '地址': '文化路164號(對面)',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '三鶯國民運動中心停車場',
#   '經度': 121.36941,
#   '緯度': 24.93614,
#   '總數': 22,
#   '行政區': '三峽區'},
#  {'可借': 6,
#   '可還': 9,
#   '地址': '國光街322號(對側)',
#   '日期時間': '2024-06-22 14:06:20',
#   '狀態': '營業中',
#   '站點名稱': '國光街330巷口',
#   '經度': 121.37212,
#   '緯度': 24.93942,
#   '總數': 16,
#   '行政區': '三峽區'},
#  {'可借': 1,
#   '可還': 15,
#   '地址': '添福15號之33(對側)',
#   '日期時間': '2024-06-22 13:28:21',
#   '狀態': '營業中',
#   '站點名稱': '添福里(添福15號之33)',
#   '經度': 121.37254,
#   '緯度': 24.90475,
#   '總數': 16,
#   '行政區': '三峽區'},
#  {'可借': 11,
#   '可還': 29,
#   '地址': '民權路1號',
#   '日期時間': '2024-06-22 13:23:19',
#   '狀態': '營業中',
#   '站點名稱': '華南頂埔科技大樓',
#   '經度': 121.41716,
#   '緯度': 24.96046,
#   '總數': 40,
#   '行政區': '土城區'},
#  {'可借': 2,
#   '可還': 26,
#   '地址': '學士路41號(前)',
#   '日期時間': '2024-06-22 14:50:35',
#   '狀態': '營業中',
#   '站點名稱': '新北高工(學士路)',
#   '經度': 121.45277,
#   '緯度': 24.98216,
#   '總數': 28,
#   '行政區': '土城區'},
#  {'可借': 8,
#   '可還': 34,
#   '地址': '延吉街381巷與延吉街口',
#   '日期時間': '2024-06-22 14:43:20',
#   '狀態': '營業中',
#   '站點名稱': '清水社區公園',
#   '經度': 121.46353,
#   '緯度': 24.98382,
#   '總數': 42,
#   '行政區': '土城區'},
#  {'可借': 18,
#   '可還': 21,
#   '地址': '仁愛路12號旁',
#   '日期時間': '2024-06-22 14:49:23',
#   '狀態': '營業中',
#   '站點名稱': '土城仁愛社區公園',
#   '經度': 121.46035,
#   '緯度': 24.98071,
#   '總數': 39,
#   '行政區': '土城區'},
#  {'可借': 5,
#   '可還': 32,
#   '地址': '青雲路449號(對面)',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '清和里(青雲路)',
#   '經度': 121.45874,
#   '緯度': 24.97513,
#   '總數': 37,
#   '行政區': '土城區'},
#  {'可借': 1,
#   '可還': 63,
#   '地址': '龍山一街與金城路二段路口',
#   '日期時間': '2024-06-22 14:49:23',
#   '狀態': '營業中',
#   '站點名稱': '斬龍山遺址文化公園',
#   '經度': 121.4477,
#   '緯度': 24.97666,
#   '總數': 64,
#   '行政區': '土城區'},
#  {'可借': 23,
#   '可還': 30,
#   '地址': '中央路一段274號(對面)',
#   '日期時間': '2024-06-22 14:43:20',
#   '狀態': '營業中',
#   '站點名稱': '中央路一段292巷口',
#   '經度': 121.44383,
#   '緯度': 24.98279,
#   '總數': 53,
#   '行政區': '土城區'},
#  {'可借': 2,
#   '可還': 28,
#   '地址': '中華路二段165號前(天橋下)',
#   '日期時間': '2024-06-22 14:37:14',
#   '狀態': '營業中',
#   '站點名稱': '中華城林路口',
#   '經度': 121.43883,
#   '緯度': 24.97525,
#   '總數': 30,
#   '行政區': '土城區'},
#  {'可借': 9,
#   '可還': 20,
#   '地址': '中州路28巷30號',
#   '日期時間': '2024-06-22 14:44:20',
#   '狀態': '營業中',
#   '站點名稱': '頂埔市場',
#   '經度': 121.41504,
#   '緯度': 24.95816,
#   '總數': 29,
#   '行政區': '土城區'},
#  {'可借': 1,
#   '可還': 55,
#   '地址': '裕民路195巷旁',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '土城綜合體育場',
#   '經度': 121.45423,
#   '緯度': 24.98367,
#   '總數': 56,
#   '行政區': '土城區'},
#  {'可借': 44,
#   '可還': 47,
#   '地址': '裕生路67巷14號前人行道(東側)',
#   '日期時間': '2024-06-22 14:53:19',
#   '狀態': '營業中',
#   '站點名稱': '捷運海山站(1號出口)',
#   '經度': 121.44855,
#   '緯度': 24.98441,
#   '總數': 94,
#   '行政區': '土城區'},
#  {'可借': 6,
#   '可還': 36,
#   '地址': '學成路72號對面公園(西南側)',
#   '日期時間': '2024-06-22 14:35:23',
#   '狀態': '營業中',
#   '站點名稱': '學成公園',
#   '經度': 121.45151,
#   '緯度': 24.98803,
#   '總數': 42,
#   '行政區': '土城區'},
#  {'可借': 26,
#   '可還': 42,
#   '地址': '中央路二段66號對面(東側)',
#   '日期時間': '2024-06-22 14:53:20',
#   '狀態': '營業中',
#   '站點名稱': '員和公園',
#   '經度': 121.44275033207957,
#   '緯度': 24.978918316048684,
#   '總數': 68,
#   '行政區': '土城區'},
#  {'可借': 41,
#   '可還': 28,
#   '地址': '捷運土城站公車站牌旁人行道',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '捷運土城站(2號出口)',
#   '經度': 121.44395,
#   '緯度': 24.9728,
#   '總數': 69,
#   '行政區': '土城區'},
#  {'可借': 17,
#   '可還': 23,
#   '地址': '金城路一段18號旁(西側)',
#   '日期時間': '2024-06-22 14:40:32',
#   '狀態': '營業中',
#   '站點名稱': '金城忠義路口',
#   '經度': 121.44024,
#   '緯度': 24.9691,
#   '總數': 40,
#   '行政區': '土城區'},
#  {'可借': 10,
#   '可還': 37,
#   '地址': '中央路三段112號對面人行道(南側)',
#   '日期時間': '2024-06-22 14:44:20',
#   '狀態': '營業中',
#   '站點名稱': '捷運永寧站(2號出口)',
#   '經度': 121.43554,
#   '緯度': 24.96613,
#   '總數': 47,
#   '行政區': '土城區'},
#  {'可借': 1,
#   '可還': 37,
#   '地址': '亞洲路9號旁人行道(東側)',
#   '日期時間': '2024-06-22 14:54:14',
#   '狀態': '營業中',
#   '站點名稱': '亞洲員安路口',
#   '經度': 121.43485,
#   '緯度': 24.97256,
#   '總數': 38,
#   '行政區': '土城區'},
#  {'可借': 12,
#   '可還': 35,
#   '地址': '金城路三段41號前(南側)',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '金城立德路口',
#   '經度': 121.46602,
#   '緯度': 24.98689,
#   '總數': 47,
#   '行政區': '土城區'},
#  {'可借': 33,
#   '可還': 27,
#   '地址': '金城路2段266號旁(西側陸橋旁)',
#   '日期時間': '2024-06-22 14:53:19',
#   '狀態': '營業中',
#   '站點名稱': '金城立體停車場',
#   '經度': 121.45795,
#   '緯度': 24.98367,
#   '總數': 60,
#   '行政區': '土城區'},
#  {'可借': 10,
#   '可還': 22,
#   '地址': '永寧路18號(對面)',
#   '日期時間': '2024-06-22 14:46:21',
#   '狀態': '營業中',
#   '站點名稱': '土城國中',
#   '經度': 121.43037,
#   '緯度': 24.96243,
#   '總數': 32,
#   '行政區': '土城區'},
#  {'可借': 11,
#   '可還': 17,
#   '地址': '土城區三民路23巷8弄(公園裡面)',
#   '日期時間': '2024-06-22 14:16:20',
#   '狀態': '營業中',
#   '站點名稱': '沛陂社區公園',
#   '經度': 121.41969877977414,
#   '緯度': 24.963262311576905,
#   '總數': 28,
#   '行政區': '土城區'},
#  {'可借': 31,
#   '可還': 35,
#   '地址': '中央路四段53號(前)',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '捷運頂埔站(2號出口)',
#   '經度': 121.4178,
#   '緯度': 24.95852,
#   '總數': 66,
#   '行政區': '土城區'},
#  {'可借': 6,
#   '可還': 34,
#   '地址': '中央路四段205號(頂埔國小校門口)(鄰近土城親子分館)',
#   '日期時間': '2024-06-22 14:38:20',
#   '狀態': '營業中',
#   '站點名稱': '頂埔國小',
#   '經度': 121.4144,
#   '緯度': 24.95636,
#   '總數': 40,
#   '行政區': '土城區'},
#  {'可借': 4,
#   '可還': 39,
#   '地址': '中央路四段285號',
#   '日期時間': '2024-06-22 14:22:20',
#   '狀態': '營業中',
#   '站點名稱': '頂新祖田市民活動中心',
#   '經度': 121.41211,
#   '緯度': 24.95319,
#   '總數': 43,
#   '行政區': '土城區'},
#  {'可借': 72,
#   '可還': 11,
#   '地址': '海山路/樂利街(西北側)',
#   '日期時間': '2024-06-22 14:52:15',
#   '狀態': '營業中',
#   '站點名稱': '捷運海山站(3號出口)',
#   '經度': 121.44911,
#   '緯度': 24.98639,
#   '總數': 99,
#   '行政區': '土城區'},
#  {'可借': 1,
#   '可還': 26,
#   '地址': '大安路8號對面(西側)',
#   '日期時間': '2024-06-22 14:31:14',
#   '狀態': '營業中',
#   '站點名稱': '大安中央路口',
#   '經度': 121.43264,
#   '緯度': 24.96576,
#   '總數': 27,
#   '行政區': '土城區'},
#  {'可借': 16,
#   '可還': 26,
#   '地址': '中山路1號',
#   '日期時間': '2024-06-22 14:37:20',
#   '狀態': '營業中',
#   '站點名稱': '中山1號科技總部',
#   '經度': 121.41212396244534,
#   '緯度': 24.96044660965163,
#   '總數': 42,
#   '行政區': '土城區'},
#  {'可借': 12,
#   '可還': 19,
#   '地址': '土城區中華路二段91~95號(人行道)',
#   '日期時間': '2024-06-22 14:46:21',
#   '狀態': '營業中',
#   '站點名稱': '長風社區',
#   '經度': 121.43937,
#   '緯度': 24.97811,
#   '總數': 31,
#   '行政區': '土城區'},
#  {'可借': 8,
#   '可還': 14,
#   '地址': '中央路二段288號(前)',
#   '日期時間': '2024-06-22 14:33:19',
#   '狀態': '營業中',
#   '站點名稱': '中央慶利街口(風華綠中央社區)',
#   '經度': 121.44052,
#   '緯度': 24.97338,
#   '總數': 22,
#   '行政區': '土城區'},
#  {'可借': 0,
#   '可還': 40,
#   '地址': '金城路二段200號(旁)',
#   '日期時間': '2024-06-22 14:31:14',
#   '狀態': '營業中',
#   '站點名稱': '金城裕民路口(金城舞社區)',
#   '經度': 121.45466,
#   '緯度': 24.98156,
#   '總數': 40,
#   '行政區': '土城區'},
#  {'可借': 5,
#   '可還': 36,
#   '地址': '青雲路449號(對面)',
#   '日期時間': '2024-06-22 13:12:20',
#   '狀態': '營業中',
#   '站點名稱': '青雲路451巷口(紐約艾美社區)',
#   '經度': 121.45873,
#   '緯度': 24.97475,
#   '總數': 41,
#   '行政區': '土城區'},
#  {'可借': 27,
#   '可還': 20,
#   '地址': '學士路/學府路口(西北側建案基地)',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '學士學府路口(大苑社區)',
#   '經度': 121.44580101471448,
#   '緯度': 24.976958449938596,
#   '總數': 47,
#   '行政區': '土城區'},
#  {'可借': 1,
#   '可還': 56,
#   '地址': '學府路一段241號前',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '新北高工',
#   '經度': 121.45054,
#   '緯度': 24.98344,
#   '總數': 57,
#   '行政區': '土城區'},
#  {'可借': 2,
#   '可還': 11,
#   '地址': '中華路一段/裕華街口(東北側)',
#   '日期時間': '2024-06-22 14:50:34',
#   '狀態': '營業中',
#   '站點名稱': '中華裕華街口',
#   '經度': 121.4472,
#   '緯度': 24.99003,
#   '總數': 13,
#   '行政區': '土城區'},
#  {'可借': 1,
#   '可還': 53,
#   '地址': '金城路二段218號對面(西北側)',
#   '日期時間': '2024-06-22 14:43:20',
#   '狀態': '營業中',
#   '站點名稱': '金城裕民路口(中正國中)',
#   '經度': 121.45619,
#   '緯度': 24.98288,
#   '總數': 54,
#   '行政區': '土城區'},
#  {'可借': 0,
#   '可還': 38,
#   '地址': '中華路一段185號前(東側)',
#   '日期時間': '2024-06-22 14:41:14',
#   '狀態': '營業中',
#   '站點名稱': '中華中央路一段242巷口',
#   '經度': 121.44348,
#   '緯度': 24.98551,
#   '總數': 38,
#   '行政區': '土城區'},
#  {'可借': 23,
#   '可還': 27,
#   '地址': '員林街16號對面(北側)',
#   '日期時間': '2024-06-22 14:48:20',
#   '狀態': '營業中',
#   '站點名稱': '員林社區公園',
#   '經度': 121.44328,
#   '緯度': 24.97784,
#   '總數': 50,
#   '行政區': '土城區'},
#  {'可借': 3,
#   '可還': 37,
#   '地址': '延和路180號旁(西側)',
#   '日期時間': '2024-06-22 14:35:23',
#   '狀態': '營業中',
#   '站點名稱': '延和社區公園',
#   '經度': 121.46882,
#   '緯度': 24.99018,
#   '總數': 40,
#   '行政區': '土城區'},
#  {'可借': 5,
#   '可還': 37,
#   '地址': '明德路一段240巷1-1號前(東側)',
#   '日期時間': '2024-06-22 14:53:19',
#   '狀態': '營業中',
#   '站點名稱': '青山廣場',
#   '經度': 121.45987,
#   '緯度': 24.97793,
#   '總數': 42,
#   '行政區': '土城區'},
#  {'可借': 7,
#   '可還': 33,
#   '地址': '立德路2號對面(北側)',
#   '日期時間': '2024-06-22 14:42:20',
#   '狀態': '營業中',
#   '站點名稱': '立德青雲路口',
#   '經度': 121.46102,
#   '緯度': 24.9883,
#   '總數': 40,
#   '行政區': '土城區'},
#  {'可借': 1,
#   '可還': 42,
#   '地址': '學府路一段76號前(南側)',
#   '日期時間': '2024-06-22 14:53:20',
#   '狀態': '營業中',
#   '站點名稱': '廣福派出所',
#   '經度': 121.45655,
#   '緯度': 24.98816,
#   '總數': 43,
#   '行政區': '土城區'},
#  {'可借': 2,
#   '可還': 5,
#   '地址': '延吉街291巷/延吉街253巷18弄口(西南側)',
#   '日期時間': '2024-06-22 14:39:21',
#   '狀態': '營業中',
#   '站點名稱': '延吉街291巷口',
#   '經度': 121.46716,
#   '緯度': 24.98394,
#   '總數': 10,
#   '行政區': '土城區'},
#  {'可借': 0,
#   '可還': 33,
#   '地址': '明德路一段72號前(公車站清水高中站旁)',
#   '日期時間': '2024-06-03 10:13:21',
#   '狀態': '維護中',
#   '站點名稱': '清水高中',
#   '經度': 121.46547,
#   '緯度': 24.982,
#   '總數': 33,
#   '行政區': '土城區'},
#  {'可借': 5,
#   '可還': 29,
#   '地址': '清水路68號(西側)',
#   '日期時間': '2024-06-22 14:40:32',
#   '狀態': '營業中',
#   '站點名稱': '裕民路口(清水路)',
#   '經度': 121.45616,
#   '緯度': 24.98157,
#   '總數': 34,
#   '行政區': '土城區'},
#  {'可借': 2,
#   '可還': 8,
#   '地址': '中華路一段/日新街口(西北側)',
#   '日期時間': '2024-06-22 14:22:20',
#   '狀態': '營業中',
#   '站點名稱': '中華日新街口',
#   '經度': 121.44463,
#   '緯度': 24.98756,
#   '總數': 10,
#   '行政區': '土城區'},
#  {'可借': 2,
#   '可還': 11,
#   '地址': '明德路一段139號西側',
#   '日期時間': '2024-06-22 13:51:21',
#   '狀態': '營業中',
#   '站點名稱': '清水高中(國際路)',
#   '經度': 121.46498,
#   '緯度': 24.98034,
#   '總數': 13,
#   '行政區': '土城區'},
#  {'可借': 10,
#   '可還': 8,
#   '地址': '延吉街111巷10號北側',
#   '日期時間': '2024-06-22 14:44:21',
#   '狀態': '營業中',
#   '站點名稱': '延吉街111巷1弄',
#   '經度': 121.47171,
#   '緯度': 24.98623,
#   '總數': 18,
#   '行政區': '土城區'},
#  {'可借': 0,
#   '可還': 25,
#   '地址': '忠承路30號',
#   '日期時間': '2024-06-22 13:57:20',
#   '狀態': '營業中',
#   '站點名稱': '大安市民活動中心',
#   '經度': 121.43935,
#   '緯度': 24.96595,
#   '總數': 25,
#   '行政區': '土城區'},
#  {'可借': 6,
#   '可還': 10,
#   '地址': '中央路三段38號',
#   '日期時間': '2024-06-22 13:26:19',
#   '狀態': '營業中',
#   '站點名稱': '中央中華路口(金城)',
#   '經度': 121.43808,
#   '緯度': 24.96875,
#   '總數': 16,
#   '行政區': '土城區'},
#  {'可借': 2,
#   '可還': 15,
#   '地址': '慶安街45巷11號東側',
#   '日期時間': '2024-06-22 14:52:20',
#   '狀態': '營業中',
#   '站點名稱': '土城國小(興城路)',
#   '經度': 121.44149,
#   '緯度': 24.97267,
#   '總數': 17,
#   '行政區': '土城區'},
#  {'可借': 8,
#   '可還': 12,
#   '地址': '金城路二段36號北側',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '金城龍山二街口',
#   '經度': 121.45096,
#   '緯度': 24.97881,
#   '總數': 20,
#   '行政區': '土城區'},
#  {'可借': 0,
#   '可還': 18,
#   '地址': '明德路二段73號北側',
#   '日期時間': '2024-06-22 14:19:14',
#   '狀態': '營業中',
#   '站點名稱': '新北高工(明德路)',
#   '經度': 121.4515,
#   '緯度': 24.98112,
#   '總數': 18,
#   '行政區': '土城區'},
#  {'可借': 10,
#   '可還': 5,
#   '地址': '學府路一段144巷2號南側',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '廣福國小',
#   '經度': 121.45506,
# ...
#   '經度': 121.61987,
#   '緯度': 25.00241,
#   '總數': 15,
#   '行政區': '深坑區'},
#  {'可借': 8,
#   '可還': 5,
#   '地址': '文化街56號(對側)',
#   '日期時間': '2024-06-22 14:41:20',
#   '狀態': '營業中',
#   '站點名稱': '深坑國中',
#   '經度': 121.61889,
#   '緯度': 25.00167,
#   '總數': 13,
#   '行政區': '深坑區'},
#  {'可借': 3,
#   '可還': 57,
#   '地址': '港東路161號(對面)',
#   '日期時間': '2024-06-22 14:36:19',
#   '狀態': '營業中',
#   '站點名稱': '野柳地質公園',
#   '經度': 121.69042,
#   '緯度': 25.20428,
#   '總數': 60,
#   '行政區': '萬里區'},
#  {'可借': 7,
#   '可還': 8,
#   '地址': '加投路/大鵬街口(東側)',
#   '日期時間': '2024-06-22 14:31:20',
#   '狀態': '營業中',
#   '站點名稱': '大鵬停車場',
#   '經度': 121.64711,
#   '緯度': 25.21194,
#   '總數': 15,
#   '行政區': '萬里區'},
#  {'可借': 3,
#   '可還': 10,
#   '地址': '瑪鋉路123號',
#   '日期時間': '2024-06-22 14:19:19',
#   '狀態': '營業中',
#   '站點名稱': '萬里區行政中心',
#   '經度': 121.68907,
#   '緯度': 25.17811,
#   '總數': 13,
#   '行政區': '萬里區'},
#  {'可借': 11,
#   '可還': 0,
#   '地址': '漁澳路33-2號(對面)',
#   '日期時間': '2024-06-22 06:10:28',
#   '狀態': '營業中',
#   '站點名稱': '龜吼停車場',
#   '經度': 121.68602,
#   '緯度': 25.1956,
#   '總數': 11,
#   '行政區': '萬里區'},
#  {'可借': 8,
#   '可還': 22,
#   '地址': '深澳路16-7號',
#   '日期時間': '2024-06-22 13:59:20',
#   '狀態': '營業中',
#   '站點名稱': '深澳漁港',
#   '經度': 121.81857,
#   '緯度': 25.12997,
#   '總數': 30,
#   '行政區': '瑞芳區'},
#  {'可借': 6,
#   '可還': 38,
#   '地址': '三爪子坑路115號(對面汽車停車格)',
#   '日期時間': '2024-06-22 14:48:20',
#   '狀態': '營業中',
#   '站點名稱': '瑞峰橋',
#   '經度': 121.81041,
#   '緯度': 25.10712,
#   '總數': 44,
#   '行政區': '瑞芳區'},
#  {'可借': 5,
#   '可還': 25,
#   '地址': '民生街3號',
#   '日期時間': '2024-06-22 14:46:21',
#   '狀態': '營業中',
#   '站點名稱': '瑞芳火車站',
#   '經度': 121.8065,
#   '緯度': 25.10851,
#   '總數': 30,
#   '行政區': '瑞芳區'},
#  {'可借': 4,
#   '可還': 8,
#   '地址': '員山子路23號',
#   '日期時間': '2024-06-22 13:42:20',
#   '狀態': '營業中',
#   '站點名稱': '瑞芳運動公園',
#   '經度': 121.82177,
#   '緯度': 25.10284,
#   '總數': 12,
#   '行政區': '瑞芳區'},
#  {'可借': 7,
#   '可還': 53,
#   '地址': '柴寮路70號',
#   '日期時間': '2024-06-22 14:53:19',
#   '狀態': '營業中',
#   '站點名稱': '猴硐火車站',
#   '經度': 121.82719,
#   '緯度': 25.08647,
#   '總數': 60,
#   '行政區': '瑞芳區'},
#  {'可借': 1,
#   '可還': 29,
#   '地址': '魚寮路22號南側',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '三貂嶺隧道(金字橋)',
#   '經度': 121.82316,
#   '緯度': 25.06095,
#   '總數': 30,
#   '行政區': '瑞芳區'},
#  {'可借': 18,
#   '可還': 12,
#   '地址': '永安街22號(對側)',
#   '日期時間': '2024-06-22 14:15:22',
#   '狀態': '營業中',
#   '站點名稱': '天山公園(永安街)',
#   '經度': 121.51753,
#   '緯度': 24.98652,
#   '總數': 30,
#   '行政區': '新店區'},
#  {'可借': 5,
#   '可還': 10,
#   '地址': '復興路131號(旁)',
#   '日期時間': '2024-06-22 14:27:20',
#   '狀態': '營業中',
#   '站點名稱': '國家人權博物館',
#   '經度': 121.53198,
#   '緯度': 24.98835,
#   '總數': 15,
#   '行政區': '新店區'},
#  {'可借': 43,
#   '可還': 18,
#   '地址': '中興路三段1號(旁)',
#   '日期時間': '2024-06-22 14:53:20',
#   '狀態': '營業中',
#   '站點名稱': '中興寶橋路口',
#   '經度': 121.54687,
#   '緯度': 24.97618,
#   '總數': 61,
#   '行政區': '新店區'},
#  {'可借': 21,
#   '可還': 28,
#   '地址': '寶橋路8號(前人行道)',
#   '日期時間': '2024-06-22 14:54:19',
#   '狀態': '營業中',
#   '站點名稱': '北新國小',
#   '經度': 121.54443,
#   '緯度': 24.97423,
#   '總數': 49,
#   '行政區': '新店區'},
#  {'可借': 18,
#   '可還': 52,
#   '地址': '民權路282號(旁)',
#   '日期時間': '2024-06-22 14:46:21',
#   '狀態': '營業中',
#   '站點名稱': '捷運十四張站',
#   '經度': 121.52833,
#   '緯度': 24.983819,
#   '總數': 70,
#   '行政區': '新店區'},
#  {'可借': 44,
#   '可還': 5,
#   '地址': '中山路/央北一路口',
#   '日期時間': '2024-06-22 14:51:21',
#   '狀態': '營業中',
#   '站點名稱': '陽光橋',
#   '經度': 121.52477,
#   '緯度': 24.97924,
#   '總數': 50,
#   '行政區': '新店區'},
#  {'可借': 21,
#   '可還': 8,
#   '地址': '環河路23號(旁捷運站內)',
#   '日期時間': '2024-06-22 14:44:20',
#   '狀態': '營業中',
#   '站點名稱': '捷運小碧潭站(1號出口)',
#   '經度': 121.53029,
#   '緯度': 24.97152,
#   '總數': 29,
#   '行政區': '新店區'},
#  {'可借': 17,
#   '可還': 28,
#   '地址': '三民路161號(旁)',
#   '日期時間': '2024-06-22 14:50:35',
#   '狀態': '營業中',
#   '站點名稱': '新店高中',
#   '經度': 121.53421,
#   '緯度': 24.97418,
#   '總數': 45,
#   '行政區': '新店區'},
#  {'可借': 18,
#   '可還': 18,
#   '地址': '三民路34號(前)',
#   '日期時間': '2024-06-22 14:51:21',
#   '狀態': '營業中',
#   '站點名稱': '中正國小',
#   '經度': 121.53646,
#   '緯度': 24.9714,
#   '總數': 36,
#   '行政區': '新店區'},
#  {'可借': 10,
#   '可還': 29,
#   '地址': '三民路18號(旁)',
#   '日期時間': '2024-06-22 14:52:20',
#   '狀態': '營業中',
#   '站點名稱': '崇光女中',
#   '經度': 121.53904,
#   '緯度': 24.97156,
#   '總數': 39,
#   '行政區': '新店區'},
#  {'可借': 24,
#   '可還': 20,
#   '地址': '寶橋路78巷10號(旁高速公路橋下空間)',
#   '日期時間': '2024-06-22 14:48:19',
#   '狀態': '營業中',
#   '站點名稱': '寶橋路78巷',
#   '經度': 121.5476,
#   '緯度': 24.97368,
#   '總數': 44,
#   '行政區': '新店區'},
#  {'可借': 23,
#   '可還': 21,
#   '地址': '寶橋路235巷2號(旁)',
#   '日期時間': '2024-06-22 14:27:20',
#   '狀態': '營業中',
#   '站點名稱': '寶橋路235巷口',
#   '經度': 121.55234,
#   '緯度': 24.97955,
#   '總數': 44,
#   '行政區': '新店區'},
#  {'可借': 33,
#   '可還': 27,
#   '地址': '民族路110號東側',
#   '日期時間': '2024-06-22 14:49:23',
#   '狀態': '營業中',
#   '站點名稱': '小金門友誼公園',
#   '經度': 121.53791,
#   '緯度': 24.97699,
#   '總數': 60,
#   '行政區': '新店區'},
#  {'可借': 15,
#   '可還': 19,
#   '地址': '行政街20號北側',
#   '日期時間': '2024-06-22 14:51:20',
#   '狀態': '營業中',
#   '站點名稱': '五峰國中',
#   '經度': 121.54311,
#   '緯度': 24.96601,
#   '總數': 34,
#   '行政區': '新店區'},
#  {'可借': 28,
#   '可還': 3,
#   '地址': '新北市新店區中正路700巷3號',
#   '日期時間': '2024-06-22 14:50:35',
#   '狀態': '營業中',
#   '站點名稱': '大鵬華城',
#   '經度': 121.53398,
#   '緯度': 24.99116,
#   '總數': 31,
#   '行政區': '新店區'},
#  {'可借': 33,
#   '可還': 59,
#   '地址': '中興路三段224號(對面)',
#   '日期時間': '2024-06-22 14:43:19',
#   '狀態': '營業中',
#   '站點名稱': '捷運大坪林站(5號出口)',
#   '經度': 121.54376,
#   '緯度': 24.98288,
#   '總數': 92,
#   '行政區': '新店區'},
#  {'可借': 26,
#   '可還': 14,
#   '地址': '北新路二段/北新路二段97巷',
#   '日期時間': '2024-06-22 14:38:20',
#   '狀態': '營業中',
#   '站點名稱': '忠誠里(北新路2段97巷)',
#   '經度': 121.54278,
#   '緯度': 24.97427,
#   '總數': 40,
#   '行政區': '新店區'},
#  {'可借': 17,
#   '可還': 25,
#   '地址': '中央四街64號對面',
#   '日期時間': '2024-06-22 14:41:20',
#   '狀態': '營業中',
#   '站點名稱': '新店公有中央市場',
#   '經度': 121.52729,
#   '緯度': 24.97531,
#   '總數': 42,
#   '行政區': '新店區'},
#  {'可借': 26,
#   '可還': 6,
#   '地址': '建國路259號前人行道',
#   '日期時間': '2024-06-22 14:49:23',
#   '狀態': '營業中',
#   '站點名稱': '建國民權路口',
#   '經度': 121.53746,
#   '緯度': 24.98318,
#   '總數': 32,
#   '行政區': '新店區'},
#  {'可借': 0,
#   '可還': 55,
#   '地址': '中興路一段34號前(高架橋下停車場)',
#   '日期時間': '2024-06-22 14:22:51',
#   '狀態': '營業中',
#   '站點名稱': '捷運新店站',
#   '經度': 121.53866,
#   '緯度': 24.95861,
#   '總數': 55,
#   '行政區': '新店區'},
#  {'可借': 10,
#   '可還': 15,
#   '地址': '安興路67號對面空地 (高架橋下)',
#   '日期時間': '2024-06-22 14:44:21',
#   '狀態': '營業中',
#   '站點名稱': '安和市民活動中心',
#   '經度': 121.51569,
#   '緯度': 24.97532,
#   '總數': 25,
#   '行政區': '新店區'},
#  {'可借': 5,
#   '可還': 39,
#   '地址': '新店區安和路二段163號(東南側空地)',
#   '日期時間': '2024-06-22 14:17:35',
#   '狀態': '營業中',
#   '站點名稱': '安和公園',
#   '經度': 121.51885,
#   '緯度': 24.97411,
#   '總數': 44,
#   '行政區': '新店區'},
#  {'可借': 38,
#   '可還': 6,
#   '地址': '中興路三段6號(旁)',
#   '日期時間': '2024-06-22 14:37:20',
#   '狀態': '營業中',
#   '站點名稱': '綠湖公園',
#   '經度': 121.54751,
#   '緯度': 24.97756,
#   '總數': 44,
#   '行政區': '新店區'},
#  {'可借': 9,
#   '可還': 20,
#   '地址': '安成街26號至36號對面',
#   '日期時間': '2024-06-22 14:51:20',
#   '狀態': '營業中',
#   '站點名稱': '安成安德街口',
#   '經度': 121.50999,
#   '緯度': 24.96115,
#   '總數': 29,
#   '行政區': '新店區'},
#  {'可借': 1,
#   '可還': 19,
#   '地址': '新烏路一段11弄11號(對面)',
#   '日期時間': '2024-06-22 10:16:19',
#   '狀態': '營業中',
#   '站點名稱': '青潭河濱公園',
#   '經度': 121.5474,
#   '緯度': 24.95091,
#   '總數': 20,
#   '行政區': '新店區'},
#  {'可借': 16,
#   '可還': 14,
#   '地址': '安德街2號(前)',
#   '日期時間': '2024-06-22 14:35:22',
#   '狀態': '營業中',
#   '站點名稱': '安康立體停車場',
#   '經度': 121.51267,
#   '緯度': 24.96261,
#   '總數': 30,
#   '行政區': '新店區'},
#  {'可借': 13,
#   '可還': 12,
#   '地址': '北宜路二段399號(旁)',
#   '日期時間': '2024-06-22 14:51:21',
#   '狀態': '營業中',
#   '站點名稱': '中印青潭廠',
#   '經度': 121.55947,
#   '緯度': 24.95446,
#   '總數': 25,
#   '行政區': '新店區'},
#  {'可借': 2,
#   '可還': 90,
#   '地址': '中正路489號(旁)',
#   '日期時間': '2024-06-22 14:52:20',
#   '狀態': '營業中',
#   '站點名稱': '中正民權路口',
#   '經度': 121.5336,
#   '緯度': 24.98263,
#   '總數': 92,
#   '行政區': '新店區'},
#  {'可借': 8,
#   '可還': 28,
#   '地址': '中正路75巷至中正路95巷間',
#   '日期時間': '2024-06-22 14:53:20',
#   '狀態': '營業中',
#   '站點名稱': '惠國市場',
#   '經度': 121.54338,
#   '緯度': 24.97042,
#   '總數': 36,
#   '行政區': '新店區'},
#  {'可借': 15,
#   '可還': 15,
#   '地址': '中興路二段41號(前)',
#   '日期時間': '2024-06-22 14:43:20',
#   '狀態': '營業中',
#   '站點名稱': '中興中正路口',
#   '經度': 121.54617,
#   '緯度': 24.96991,
#   '總數': 30,
#   '行政區': '新店區'},
#  {'可借': 66,
#   '可還': 27,
#   '地址': '北新路一段88巷1號(對面)',
#   '日期時間': '2024-06-22 14:54:19',
#   '狀態': '營業中',
#   '站點名稱': '新店行政園區',
#   '經度': 121.54205,
#   '緯度': 24.96757,
#   '總數': 93,
#   '行政區': '新店區'},
#  {'可借': 5,
#   '可還': 22,
#   '地址': '光明街185號(對面)',
#   '日期時間': '2024-06-22 14:41:19',
#   '狀態': '營業中',
#   '站點名稱': '光明街',
#   '經度': 121.54009,
#   '緯度': 24.96316,
#   '總數': 27,
#   '行政區': '新店區'},
#  {'可借': 11,
#   '可還': 23,
#   '地址': '中華路3號(對面)',
#   '日期時間': '2024-06-22 14:48:20',
#   '狀態': '營業中',
#   '站點名稱': '捷運新店區公所站(1號出口)',
#   '經度': 121.54101,
#   '緯度': 24.96737,
#   '總數': 42,
#   '行政區': '新店區'},
#  {'可借': 20,
#   '可還': 12,
#   '地址': '新店區北新路三段105巷2號(路側)',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '新北市立圖書館新店分館',
#   '經度': 121.5409,
#   '緯度': 24.98214,
#   '總數': 35,
#   '行政區': '新店區'},
#  {'可借': 18,
#   '可還': 30,
#   '地址': '中興路三段/寶慶街',
#   '日期時間': '2024-06-22 14:24:20',
#   '狀態': '營業中',
#   '站點名稱': '中興寶慶街口',
#   '經度': 121.54195,
#   '緯度': 24.98694,
#   '總數': 49,
#   '行政區': '新店區'},
#  {'可借': 21,
#   '可還': 9,
#   '地址': '民生路156巷80號(旁)',
#   '日期時間': '2024-06-22 14:36:20',
#   '狀態': '營業中',
#   '站點名稱': '民生路156巷',
#   '經度': 121.52751,
#   '緯度': 24.98202,
#   '總數': 31,
#   '行政區': '新店區'},
#  {'可借': 12,
#   '可還': 24,
#   '地址': '新和街109號',
#   '日期時間': '2024-06-22 14:36:20',
#   '狀態': '營業中',
#   '站點名稱': '新和活動中心',
#   '經度': 121.52183,
#   '緯度': 24.98677,
#   '總數': 37,
#   '行政區': '新店區'},
#  {'可借': 12,
#   '可還': 24,
#   '地址': '安和路三段100號',
#   '日期時間': '2024-06-22 13:29:19',
#   '狀態': '營業中',
#   '站點名稱': '新店新和國小',
#   '經度': 121.51768,
#   '緯度': 24.98498,
#   '總數': 36,
#   '行政區': '新店區'},
#  {'可借': 0,
#   '可還': 21,
#   '地址': '安興路121號',
#   '日期時間': '2024-06-22 14:52:15',
#   '狀態': '營業中',
#   '站點名稱': '陽光Park社區',
#   '經度': 121.51555,
#   '緯度': 24.9794,
#   '總數': 21,
#   '行政區': '新店區'},
#  {'可借': 8,
#   '可還': 30,
#   '地址': '安興路25號',
#   '日期時間': '2024-06-22 14:38:20',
#   '狀態': '營業中',
#   '站點名稱': '安康高中',
#   '經度': 121.51521,
#   '緯度': 24.96927,
#   '總數': 38,
#   '行政區': '新店區'},
#  {'可借': 17,
#   '可還': 13,
#   '地址': '安民街73號',
#   '日期時間': '2024-06-22 14:48:20',
#   '狀態': '營業中',
#   '站點名稱': '柴埕市民活動中心',
#   '經度': 121.51648,
#   '緯度': 24.96678,
#   '總數': 30,
#   '行政區': '新店區'},
#  {'可借': 7,
#   '可還': 25,
#   '地址': '安民街3巷25號北側',
#   '日期時間': '2024-06-22 14:47:20',
#   '狀態': '營業中',
#   '站點名稱': '安光公園',
#   '經度': 121.51446,
#   '緯度': 24.96423,
#   '總數': 32,
#   '行政區': '新店區'},
#  {'可借': 3,
#   '可還': 19,
#   '地址': '安忠路52號',
#   '日期時間': '2024-06-22 13:56:20',
#   '狀態': '營業中',
#   '站點名稱': '安居公教住宅',
#   '經度': 121.51293,
#   '緯度': 24.9595,
#   '總數': 22,
#   '行政區': '新店區'},
#  {'可借': 1,
#   '可還': 36,
#   '地址': '碧潭路2號',
#   '日期時間': '2024-06-22 14:40:32',
#   '狀態': '營業中',
#   '站點名稱': '碧潭西岸',
#   '經度': 121.5348,
#   '緯度': 24.95656,
#   '總數': 37,
#   '行政區': '新店區'},
#  {'可借': 9,
#   '可還': 17,
#   '地址': '新店路36號西側',
#   '日期時間': '2024-06-22 14:49:23',
#   '狀態': '營業中',
#   '站點名稱': '碧潭渡船頭',
#   '經度': 121.53746,
#   '緯度': 24.9531,
#   '總數': 26,
#   '行政區': '新店區'},
#  {'可借': 0,
#   '可還': 25,
#   '地址': '北宜路一段107-2號',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '文山國中',
#   '經度': 121.53937,
#   '緯度': 24.95521,
#   '總數': 25,
#   '行政區': '新店區'},
#  {'可借': 4,
#   '可還': 23,
#   '地址': '北宜路二段80號',
#   '日期時間': '2024-06-22 11:58:17',
#   '狀態': '營業中',
#   '站點名稱': '青潭國小',
#   '經度': 121.55181,
#   '緯度': 24.9531,
#   '總數': 27,
#   '行政區': '新店區'},
#  {'可借': 5,
#   '可還': 24,
#   '地址': '中正路284巷4弄3號南側',
#   '日期時間': '2024-06-22 14:50:35',
#   '狀態': '營業中',
#   '站點名稱': '中正路284巷',
#   '經度': 121.53842,
#   '緯度': 24.9747,
#   '總數': 29,
#   '行政區': '新店區'},
#  {'可借': 24,
#   '可還': 28,
#   '地址': '央北二路十四張口(西南側人行道)',
#   '日期時間': '2024-06-22 14:51:21',
#   '狀態': '營業中',
#   '站點名稱': '央北社會住宅',
#   '經度': 121.52643,
#   '緯度': 24.98263,
#   '總數': 58,
#   '行政區': '新店區'},
#  {'可借': 2,
#   '可還': 19,
#   '地址': '五峰路63巷/中興路二段100巷口(天橋旁)',
#   '日期時間': '2024-06-22 14:42:15',
#   '狀態': '營業中',
#   '站點名稱': '中興路2段100巷口',
#   '經度': 121.5475,
#   '緯度': 24.97136,
#   '總數': 21,
#   '行政區': '新店區'},
#  {'可借': 8,
#   '可還': 32,
#   '地址': '建國路289號旁空地',
#   '日期時間': '2024-06-22 14:47:20',
#   '狀態': '營業中',
#   '站點名稱': '台北慈濟醫院',
#   '經度': 121.537,
#   '緯度': 24.9859,
#   '總數': 40,
#   '行政區': '新店區'},
#  {'可借': 24,
#   '可還': 18,
#   '地址': '北新路二段/北新路二段121巷',
#   '日期時間': '2024-06-22 14:54:19',
#   '狀態': '營業中',
#   '站點名稱': '捷運七張站(1號出口)',
#   '經度': 121.542767,
#   '緯度': 24.974996,
#   '總數': 42,
#   '行政區': '新店區'},
#  {'可借': 2,
#   '可還': 40,
#   '地址': '北新路三段129號(右側人行道)',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '捷運大坪林站(1號出口)',
#   '經度': 121.541,
#   '緯度': 24.9828,
#   '總數': 47,
#   '行政區': '新店區'},
#  {'可借': 20,
#   '可還': 22,
#   '地址': '中央路97號(對面)',
#   '日期時間': '2024-06-22 14:53:20',
#   '狀態': '營業中',
#   '站點名稱': '新店高中(中央路)',
#   '經度': 121.53103,
#   '緯度': 24.97508,
#   '總數': 42,
#   '行政區': '新店區'},
#  {'可借': 22,
#   '可還': 18,
#   '地址': '十四張路/央北二路口(西北側人行道)',
#   '日期時間': '2024-06-22 14:21:20',
#   '狀態': '營業中',
#   '站點名稱': '十四張央北二路口(波爾多社區)',
#   '經度': 121.52635,
#   '緯度': 24.98285,
#   '總數': 40,
#   '行政區': '新店區'},
#  {'可借': 17,
#   '可還': 18,
#   '地址': '寶高路10號(旁)',
#   '日期時間': '2024-06-22 14:46:21',
#   '狀態': '營業中',
#   '站點名稱': '寶高智慧產業園區',
#   '經度': 121.551,
#   '緯度': 24.9775,
#   '總數': 35,
#   '行政區': '新店區'},
#  {'可借': 12,
#   '可還': 10,
#   '地址': '斯馨路70巷60號(旁)',
#   '日期時間': '2024-06-22 14:31:20',
#   '狀態': '營業中',
#   '站點名稱': '順德街(御中央3社區)',
#   '經度': 121.53,
#   '緯度': 24.9789,
#   '總數': 22,
#   '行政區': '新店區'},
#  {'可借': 2,
#   '可還': 9,
#   '地址': '寶興路47號西側',
#   '日期時間': '2024-06-22 14:43:20',
#   '狀態': '營業中',
#   '站點名稱': '台灣科技總部',
#   '經度': 121.54905,
#   '緯度': 24.97344,
#   '總數': 11,
#   '行政區': '新店區'},
#  {'可借': 15,
#   '可還': 25,
#   '地址': '中央路3號對面(西側)',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '央北三中央路口(全陽大璽)',
#   '經度': 121.53339,
#   '緯度': 24.97878,
#   '總數': 40,
#   '行政區': '新店區'},
#  {'可借': 2,
#   '可還': 13,
#   '地址': '直潭路與直潭二街口',
#   '日期時間': '2024-06-22 00:37:19',
#   '狀態': '營業中',
#   '站點名稱': '直潭淨水廠(直潭二街)',
#   '經度': 121.53536,
#   '緯度': 24.9431,
#   '總數': 15,
#   '行政區': '新店區'},
#  {'可借': 5,
#   '可還': 10,
#   '地址': '直潭十街與直潭九街口',
#   '日期時間': '2024-06-18 21:27:19',
#   '狀態': '營業中',
#   '站點名稱': '直潭活動中心',
#   '經度': 121.53329,
#   '緯度': 24.93893,
#   '總數': 15,
#   '行政區': '新店區'},
#  {'可借': 15,
#   '可還': 8,
#   '地址': '永平街23巷11號(旁)',
#   '日期時間': '2024-06-22 14:31:20',
#   '狀態': '營業中',
#   '站點名稱': '永平街23巷',
#   '經度': 121.51604,
#   '緯度': 24.98316,
#   '總數': 23,
#   '行政區': '新店區'},
#  {'可借': 11,
#   '可還': 9,
#   '地址': '啟文央北二路口北側',
#   '日期時間': '2024-06-22 14:43:20',
#   '狀態': '營業中',
#   '站點名稱': '十四張歷史公園(南側)',
#   '經度': 121.52844,
#   '緯度': 24.979,
#   '總數': 20,
#   '行政區': '新店區'},
#  {'可借': 2,
#   '可還': 13,
#   '地址': '二十張路129巷2弄2號(南側)',
#   '日期時間': '2024-06-22 14:43:20',
#   '狀態': '營業中',
#   '站點名稱': '大豐公園停車場',
#   '經度': 121.53587,
#   '緯度': 24.97875,
#   '總數': 15,
#   '行政區': '新店區'},
#  {'可借': 1,
#   '可還': 10,
#   '地址': '寶強路23號(前)',
#   '日期時間': '2024-06-22 14:45:16',
#   '狀態': '營業中',
#   '站點名稱': '寶強文化路口',
#   '經度': 121.54351,
#   '緯度': 24.97914,
#   '總數': 11,
#   '行政區': '新店區'},
#  {'可借': 0,
#   '可還': 12,
#   '地址': '北新路二段228巷1號',
#   '日期時間': '2024-06-22 14:40:26',
#   '狀態': '營業中',
#   '站點名稱': '北新路二段228巷口',
#   '經度': 121.54284,
#   '緯度': 24.97775,
#   '總數': 12,
#   '行政區': '新店區'},
#  {'可借': 2,
#   '可還': 11,
#   '地址': '寶中路95號(前)',
#   '日期時間': '2024-06-22 14:48:20',
#   '狀態': '營業中',
#   '站點名稱': '寶中路97巷口',
#   '經度': 121.54878,
#   '緯度': 24.98047,
#   '總數': 13,
#   '行政區': '新店區'},
#  {'可借': 3,
#   '可還': 14,
#   '地址': '寶中路136號(對面)',
#   '日期時間': '2024-06-22 14:53:20',
#   '狀態': '營業中',
#   '站點名稱': '寶中寶橋路口',
#   '經度': 121.55028,
#   '緯度': 24.97862,
#   '總數': 17,
#   '行政區': '新店區'},
#  {'可借': 12,
#   '可還': 15,
#   '地址': '寶橋路235巷18號(旁)',
#   '日期時間': '2024-06-22 12:52:20',
#   '狀態': '營業中',
#   '站點名稱': '寶橋路235巷',
#   '經度': 121.55102,
#   '緯度': 24.98278,
#   '總數': 27,
#   '行政區': '新店區'},
#  {'可借': 3,
#   '可還': 7,
#   '地址': '寶橋路29巷18號南側',
#   '日期時間': '2024-06-22 14:53:20',
#   '狀態': '營業中',
#   '站點名稱': '寶橋路29巷',
#   '經度': 121.54389,
#   '緯度': 24.97492,
#   '總數': 10,
#   '行政區': '新店區'},
#  {'可借': 5,
#   '可還': 8,
#   '地址': '中興路一段/檳榔路(西南側)',
#   '日期時間': '2024-06-22 14:54:20',
#   '狀態': '營業中',
#   '站點名稱': '中興檳榔路口',
#   '經度': 121.54185,
#   '緯度': 24.96337,
#   '總數': 13,
#   '行政區': '新店區'},
#  {'可借': 5,
#   '可還': 7,
#   '地址': '北新路一段235號(旁)',
#   '日期時間': '2024-06-22 14:47:20',
#   '狀態': '營業中',
#   '站點名稱': '北新新生街口',
#   '經度': 121.54061,
#   '緯度': 24.96561,
#   '總數': 12,
#   '行政區': '新店區'},
#  {'可借': 7,
#   '可還': 12,
#   '地址': '中興路三段138號(前)',
#   '日期時間': '2024-06-22 14:49:22',
#   '狀態': '營業中',
#   '站點名稱': '中興文化路口(東南側)',
#   '經度': 121.5445,
#   '緯度': 24.98037,
#   '總數': 19,
#   '行政區': '新店區'},
#  {'可借': 9,
#   '可還': 6,
#   '地址': '安康路三段322號',
#   '日期時間': '2024-06-22 10:19:20',
#   '狀態': '營業中',
#   '站點名稱': '雙城國小',
#   '經度': 121.48628,
#   '緯度': 24.95186,
#   '總數': 15,
#   '行政區': '新店區'},
#  {'可借': 4,
#   '可還': 7,
#   '地址': '富貴街11巷2號',
#   '日期時間': '2024-06-22 09:50:31',
#   '狀態': '營業中',
#   '站點名稱': '北城生活廣場(富貴街)',
#   '經度': 121.49409,
#   '緯度': 24.94888,
#   '總數': 11,
#   '行政區': '新店區'},
#  {'可借': 1,
#   '可還': 15,
#   '地址': '如意街112號北側',
#   '日期時間': '2024-06-22 14:41:14',
#   '狀態': '營業中',
#   '站點名稱': '中華郵政玫瑰城郵局',
#   '經度': 121.49674,
#   '緯度': 24.94702,
#   '總數': 16,
#   '行政區': '新店區'},
#  {'可借': 7,
#   '可還': 6,
#   '地址': '安民街21號東側',
#   '日期時間': '2024-06-22 14:45:23',
#   '狀態': '營業中',
#   '站點名稱': '安民街35巷口',
#   '經度': 121.51564,
#   '緯度': 24.96484,
#   '總數': 13,
#   '行政區': '新店區'}]

# %%
'YouBike2.0_下庄市場'.split('_')[-1]
# Out:
# '下庄市場'
