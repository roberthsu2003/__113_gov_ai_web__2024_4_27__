# %%
5 > 3
# Out:
# True

# %%
5 != 5
# Out:
# False

# %%
5 > 5
# Out:
# False

# %%
5 == 5
# Out:
# True

# %%
age = 19
if age >= 18:
 print("可以投票")
 print("可以考駕照")
print("應用程式結束")
# Out:
# 可以投票
# 可以考駕照
# 應用程式結束

# %%
age = 17
if age >= 18:
    print("可以投票")
    print("可以考駕照")
else:
    print("不可以投票")
    print("不可以考駕照")
 
print("應用程式結束")
# Out:
# 不可以投票
# 不可以考駕照
# 應用程式結束

# %%
scores = int(input("請輸入學生分數(最高300):"))
is_add = input("學生是否符合加分條件?(y,n)")

if is_add == 'y':
    #scores = scores * 1.05
    scores *= 1.05

print("目前學生的分數",round(scores))
# Out:
# 目前學生的分數 278
