# %%
scores = 45

if scores < 60:
    print("小於60")
else:    
    if scores < 80:
        print("大於等於60")
        print("小於80")
    else:
        print("大於等於80")
# Out:
# 小於60

# %%
scores =89

if scores < 60:
    print("小於60")
elif scores < 80:
    print("大於等於60")
    print("小於80")
else:
    print("大於等於80")
# Out:
# 大於等於80
