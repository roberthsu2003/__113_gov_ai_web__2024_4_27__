# %%
class Person():
    pass

p1 = Person()
type(p1)
# Out:
# __main__.Person

# %%
class Person():
    def __init__(self,n): #自訂的初始化
        self.name = n #建立attribute

    def __repr__(self):
        return "我是Person的實體"

p1 = Person("徐國堂")#建立實體
print(p1.name)

p2 = Person("Robert Hsu")#建立實體
print(p2.name)
# Out:
# 徐國堂
# Robert Hsu

# %%
print(p1)
print(p2)
# Out:
# 我是Person的實體
# 我是Person的實體
